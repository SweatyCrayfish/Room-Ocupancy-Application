# %% [markdown]
# ---
#
# # Final Team Project: Machine Learning IoT Application Design and Implementation
# ## Team 1 - Jason Raimondi, Sundar Sundaresan, and Viktor Veselov
# ## University of San Diego
# ## AAI-530: Data Analytics and IoT
# ## Professor An Tran
# ## 2023-02-27
#
# ---
#
# ### GitHub Repository:
# ### https://github.com/SweatyCrayfish/Room-Ocupancy-Application
# ### Final Project - ML IoT Application.ipynb
#
# ---
#
# ### Tableau Public Dashboard:
# ### https://public.tableau.com/views/RoomOcupancy/Dashboard1?:language=en-US&:display_count=n&:origin=viz_share_link
#
# ---

# %%
#cleaned modules
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import skew
from sklearn import preprocessing
import keras
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, LSTM, Activation
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, recall_score, precision_score, classification_report, mean_squared_error, precision_recall_fscore_support, r2_score
import xgboost as xgb
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Load and clean data

# %% [markdown]
# The Room Occupancy Estimation dataset can be located in the UCI Machine Learning Repository:
# https://archive.ics.uci.edu/ml/datasets/Room+Occupancy+Estimation
#
# First, we will read the dataset from a CSV file and assign to a Pandas dataframe.  Then, we will perform some initial discovery to start exploring and learning the dataset.

# %%
# create new dataframe with raw data
df_raw = pd.read_csv('Occupancy_Estimation.csv')

# %%
# view shape of dataframe
print ('Total rows in df_raw =', df_raw.shape[0])
print ('Total columns in df_raw =', df_raw.shape[1])
# Out:
# Total rows in df_raw = 10129
# Total columns in df_raw = 19

# %%
# view dataframe head
df_raw.head()
# Out:
#          Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 0  2017/12/22  10:49:41    24.94    24.75    24.56    25.38       121
# 1  2017/12/22  10:50:12    24.94    24.75    24.56    25.44       121
# 2  2017/12/22  10:50:42    25.00    24.75    24.50    25.44       121
# 3  2017/12/22  10:51:13    25.00    24.75    24.56    25.44       121
# 4  2017/12/22  10:51:44    25.00    24.75    24.56    25.44       121
#
#    S2_Light  S3_Light  S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  \
# 0        34        53        40      0.08      0.19      0.06      0.06
# 1        33        53        40      0.93      0.05      0.06      0.06
# 2        34        53        40      0.43      0.11      0.08      0.06
# 3        34        53        40      0.41      0.10      0.10      0.09
# 4        34        54        40      0.18      0.06      0.06      0.06
#
#    S5_CO2  S5_CO2_Slope  S6_PIR  S7_PIR  Room_Occupancy_Count
# 0     390      0.769231       0       0                     1
# 1     390      0.646154       0       0                     1
# 2     390      0.519231       0       0                     1
# 3     390      0.388462       0       0                     1
# 4     390      0.253846       0       0                     1

# %% [markdown]
# We can see that we have separate columns for Date and Time.  To support our later time-series machine learning prediction, we will plan to combine into a single Datetime column.

# %%
# print data types and describe data
print (df_raw.dtypes)
df_raw.describe()
# Out:
# Date                     object
# Time                     object
# S1_Temp                 float64
# S2_Temp                 float64
# S3_Temp                 float64
# S4_Temp                 float64
# S1_Light                  int64
# S2_Light                  int64
# S3_Light                  int64
# S4_Light                  int64
# S1_Sound                float64
# S2_Sound                float64
# S3_Sound                float64
# S4_Sound                float64
# S5_CO2                    int64
# S5_CO2_Slope            float64
# S6_PIR                    int64
# S7_PIR                    int64
# Room_Occupancy_Count      int64
# dtype: object
#             S1_Temp       S2_Temp       S3_Temp       S4_Temp      S1_Light  \
# count  10129.000000  10129.000000  10129.000000  10129.000000  10129.000000
# mean      25.454012     25.546059     25.056621     25.754125     25.445059
# std        0.351351      0.586325      0.427283      0.356434     51.011264
# min       24.940000     24.750000     24.440000     24.940000      0.000000
# 25%       25.190000     25.190000     24.690000     25.440000      0.000000
# 50%       25.380000     25.380000     24.940000     25.750000      0.000000
# 75%       25.630000     25.630000     25.380000     26.000000     12.000000
# max       26.380000     29.000000     26.190000     26.560000    165.000000
#
#           S2_Light      S3_Light      S4_Light      S1_Sound      S2_Sound  \
# count  10129.00000  10129.000000  10129.000000  10129.000000  10129.000000
# mean      26.01629     34.248494     13.220259      0.168178      0.120066
# std       67.30417     58.400744     19.602219      0.316709      0.266503
# min        0.00000      0.000000      0.000000      0.060000      0.040000
# 25%        0.00000      0.000000      0.000000      0.070000      0.050000
# 50%        0.00000      0.000000      0.000000      0.080000      0.050000
# 75%       14.00000     50.000000     22.000000      0.080000      0.060000
# max      258.00000    280.000000     74.000000      3.880000      3.440000
#
#            S3_Sound      S4_Sound        S5_CO2  S5_CO2_Slope        S6_PIR  \
# count  10129.000000  10129.000000  10129.000000  10129.000000  10129.000000
# mean       0.158119      0.103840    460.860401     -0.004830      0.090137
# std        0.413637      0.120683    199.964940      1.164990      0.286392
# min        0.040000      0.050000    345.000000     -6.296154      0.000000
# 25%        0.060000      0.060000    355.000000     -0.046154      0.000000
# 50%        0.060000      0.080000    360.000000      0.000000      0.000000
# 75%        0.070000      0.100000    465.000000      0.000000      0.000000
# max        3.670000      3.400000   1270.000000      8.980769      1.000000
#
#              S7_PIR  Room_Occupancy_Count
# count  10129.000000          10129.000000
# mean       0.079574              0.398559
# std        0.270645              0.893633
# min        0.000000              0.000000
# 25%        0.000000              0.000000
# 50%        0.000000              0.000000
# 75%        0.000000              0.000000
# max        1.000000              3.000000

# %% [markdown]
# We can see that we currently have 17 total numeric features (excluding Date and Time).  For our project, we will be predicting a different feature for each machine learning model developed.  To reduce complexity of our IoT system design, we will be using average values for Temperature, Light, and Sound, which will reduce the number of columns for each of these features from 4 to 1, or from 12 to 3 when considering them all.  We will create copy of the raw data and make these changes now.

# %%
# create new dataframe for modifications
df = df_raw.copy()

# %%
# create Datetime column

# combine into a single column
df['Datetime'] = df['Date'] + ' ' + df['Time']

# convert to datetime, specify that year comes first in the format
df['Datetime'] = pd.to_datetime(df['Datetime'], yearfirst=True)

# %%
# print data types and describe data
print (df.dtypes)
df.head()
# Out:
# Date                            object
# Time                            object
# S1_Temp                        float64
# S2_Temp                        float64
# S3_Temp                        float64
# S4_Temp                        float64
# S1_Light                         int64
# S2_Light                         int64
# S3_Light                         int64
# S4_Light                         int64
# S1_Sound                       float64
# S2_Sound                       float64
# S3_Sound                       float64
# S4_Sound                       float64
# S5_CO2                           int64
# S5_CO2_Slope                   float64
# S6_PIR                           int64
# S7_PIR                           int64
# Room_Occupancy_Count             int64
# Datetime                datetime64[ns]
# dtype: object
#          Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 0  2017/12/22  10:49:41    24.94    24.75    24.56    25.38       121
# 1  2017/12/22  10:50:12    24.94    24.75    24.56    25.44       121
# 2  2017/12/22  10:50:42    25.00    24.75    24.50    25.44       121
# 3  2017/12/22  10:51:13    25.00    24.75    24.56    25.44       121
# 4  2017/12/22  10:51:44    25.00    24.75    24.56    25.44       121
#
#    S2_Light  S3_Light  S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  \
# 0        34        53        40      0.08      0.19      0.06      0.06
# 1        33        53        40      0.93      0.05      0.06      0.06
# 2        34        53        40      0.43      0.11      0.08      0.06
# 3        34        53        40      0.41      0.10      0.10      0.09
# 4        34        54        40      0.18      0.06      0.06      0.06
#
#    S5_CO2  S5_CO2_Slope  S6_PIR  S7_PIR  Room_Occupancy_Count  \
# 0     390      0.769231       0       0                     1
# 1     390      0.646154       0       0                     1
# 2     390      0.519231       0       0                     1
# 3     390      0.388462       0       0                     1
# 4     390      0.253846       0       0                     1
#
#              Datetime
# 0 2017-12-22 10:49:41
# 1 2017-12-22 10:50:12
# 2 2017-12-22 10:50:42
# 3 2017-12-22 10:51:13
# 4 2017-12-22 10:51:44

# %% [markdown]
# We can see that our Datetime column is now a datetime data type.  Let's check to see if the Date and Time columns are date and time data types.

# %%
df['Date'][0]
# Out:
# '2017/12/22'

# %% [markdown]
# The Date column does not appear to be a date data type.  Let's also check the Time column.

# %%
df['Time'][0]
# Out:
# '10:49:41'

# %% [markdown]
# The Time column does not appear to be a time data type.  Let's use our Datetime column to turn the Date and Time columns into date and time data types.

# %%
# convert to date and time data types
df['Date'] = df['Datetime'].dt.date
df['Time'] = df['Datetime'].dt.time

# %% [markdown]
# Let's now recheck our Date and Time columns to verify the data types are correct.

# %%
df['Date'][0]
# Out:
# datetime.date(2017, 12, 22)

# %% [markdown]
# The Date column is now a date data type.

# %%
df['Time'][0]
# Out:
# datetime.time(10, 49, 41)

# %% [markdown]
# The Time column is now a time data type.

# %% [markdown]
# Let's review the describe() results again now that we have a numeric Datetime column that can be included in the results.

# %%
# describe, including statistics on Datetime column
df.describe(datetime_is_numeric = True)
# Out:
#             S1_Temp       S2_Temp       S3_Temp       S4_Temp      S1_Light  \
# count  10129.000000  10129.000000  10129.000000  10129.000000  10129.000000
# mean      25.454012     25.546059     25.056621     25.754125     25.445059
# min       24.940000     24.750000     24.440000     24.940000      0.000000
# 25%       25.190000     25.190000     24.690000     25.440000      0.000000
# 50%       25.380000     25.380000     24.940000     25.750000      0.000000
# 75%       25.630000     25.630000     25.380000     26.000000     12.000000
# max       26.380000     29.000000     26.190000     26.560000    165.000000
# std        0.351351      0.586325      0.427283      0.356434     51.011264
#
#           S2_Light      S3_Light      S4_Light      S1_Sound      S2_Sound  \
# count  10129.00000  10129.000000  10129.000000  10129.000000  10129.000000
# mean      26.01629     34.248494     13.220259      0.168178      0.120066
# min        0.00000      0.000000      0.000000      0.060000      0.040000
# 25%        0.00000      0.000000      0.000000      0.070000      0.050000
# 50%        0.00000      0.000000      0.000000      0.080000      0.050000
# 75%       14.00000     50.000000     22.000000      0.080000      0.060000
# max      258.00000    280.000000     74.000000      3.880000      3.440000
# std       67.30417     58.400744     19.602219      0.316709      0.266503
#
#            S3_Sound      S4_Sound        S5_CO2  S5_CO2_Slope        S6_PIR  \
# count  10129.000000  10129.000000  10129.000000  10129.000000  10129.000000
# mean       0.158119      0.103840    460.860401     -0.004830      0.090137
# min        0.040000      0.050000    345.000000     -6.296154      0.000000
# 25%        0.060000      0.060000    355.000000     -0.046154      0.000000
# 50%        0.060000      0.080000    360.000000      0.000000      0.000000
# 75%        0.070000      0.100000    465.000000      0.000000      0.000000
# max        3.670000      3.400000   1270.000000      8.980769      1.000000
# std        0.413637      0.120683    199.964940      1.164990      0.286392
#
#              S7_PIR  Room_Occupancy_Count                       Datetime
# count  10129.000000          10129.000000                          10129
# mean       0.079574              0.398559  2017-12-27 20:27:23.034554112
# min        0.000000              0.000000            2017-12-22 10:49:41
# 25%        0.000000              0.000000            2017-12-23 09:14:33
# 50%        0.000000              0.000000            2017-12-24 07:06:45
# 75%        0.000000              0.000000            2017-12-26 04:58:18
# max        1.000000              3.000000            2018-01-11 09:00:09
# std        0.270645              0.893633                            NaN

# %% [markdown]
# We can see that our IoT sensor readings start on 12/22/2017 and end on 1/11/2018.  We can also see the Room Occupany Count ranging from 0 to 3 persons.  Let's check the unique values of Date and Room Occupancy Count.

# %%
# print unique Dates
print ('Unique Dates: \n', df['Date'].unique(), '\n')

# print unique Room Occupancy Count
print ('Unique Room Occupancy Count: \n', df['Room_Occupancy_Count'].unique())
# Out:
# Unique Dates:
#  [datetime.date(2017, 12, 22) datetime.date(2017, 12, 23)
#  datetime.date(2017, 12, 24) datetime.date(2017, 12, 25)
#  datetime.date(2017, 12, 26) datetime.date(2018, 1, 10)
#  datetime.date(2018, 1, 11)]
#
# Unique Room Occupancy Count:
#  [1 2 3 0]

# %% [markdown]
# We can see that data was not collected for every day in the entire range of dates, as there is a gap between 12/26/2017 and 1/10/2018.  We can also see that Christmas Day and days surrounding the Holiday are included, so it's possible that these were days when there was no room occupancy.  We can also see that the Room Occupancy does range from 0 to 3 occupants, as was described in the dataset source information.  Our row counts are all equal, so there does not appear to be any missing data.  We will check to be sure.

# %%
# Visualize any missing data
df.isna().sum().plot.bar();

# %% [markdown]
# The bar graph confirms that we are not missing any data.  Our IoT system is based on a single IoT device in a room, versus multiple devices that were used to generate the original dataset.  To adapt the dataset to our IoT system design, we will consolidate Temperature, Light, and Sound columns into corresponding average columns.  This will simulate these readings coming from single sensors, as in our IoT system design.  It will also reduce the complexity of the dataset.

# %%
# create new columns for combined (average) temperature, light, and sound
df['Temp'] = (df['S1_Temp'] + df['S2_Temp'] + df['S3_Temp'] + df['S4_Temp'] / 4)
df['Light'] = (df['S1_Light'] + df['S2_Light'] + df['S3_Light'] + df['S4_Light'] / 4)
df['Sound'] = (df['S1_Sound'] + df['S2_Sound'] + df['S3_Sound'] + df['S4_Sound'] / 4)

# view dataframe
df.head()
# Out:
#          Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 0  2017-12-22  10:49:41    24.94    24.75    24.56    25.38       121
# 1  2017-12-22  10:50:12    24.94    24.75    24.56    25.44       121
# 2  2017-12-22  10:50:42    25.00    24.75    24.50    25.44       121
# 3  2017-12-22  10:51:13    25.00    24.75    24.56    25.44       121
# 4  2017-12-22  10:51:44    25.00    24.75    24.56    25.44       121
#
#    S2_Light  S3_Light  S4_Light  ...  S4_Sound  S5_CO2  S5_CO2_Slope  S6_PIR  \
# 0        34        53        40  ...      0.06     390      0.769231       0
# 1        33        53        40  ...      0.06     390      0.646154       0
# 2        34        53        40  ...      0.06     390      0.519231       0
# 3        34        53        40  ...      0.09     390      0.388462       0
# 4        34        54        40  ...      0.06     390      0.253846       0
#
#    S7_PIR  Room_Occupancy_Count            Datetime    Temp  Light   Sound
# 0       0                     1 2017-12-22 10:49:41  80.595  218.0  0.3450
# 1       0                     1 2017-12-22 10:50:12  80.610  217.0  1.0550
# 2       0                     1 2017-12-22 10:50:42  80.610  218.0  0.6350
# 3       0                     1 2017-12-22 10:51:13  80.670  218.0  0.6325
# 4       0                     1 2017-12-22 10:51:44  80.670  219.0  0.3150
#
# [5 rows x 23 columns]

# %% [markdown]
# Let's now drop the separate reading colums for temperature, light, and sound then view our dataframe again.

# %%
# drop individual reading columns for temperature, light, and sound
df = df.drop(columns=['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp'])
df = df.drop(columns=['S1_Light', 'S2_Light', 'S3_Light', 'S4_Light'])
df = df.drop(columns=['S1_Sound', 'S2_Sound', 'S3_Sound', 'S4_Sound'])

# view dataframe
df.head()
# Out:
#          Date      Time  S5_CO2  S5_CO2_Slope  S6_PIR  S7_PIR  \
# 0  2017-12-22  10:49:41     390      0.769231       0       0
# 1  2017-12-22  10:50:12     390      0.646154       0       0
# 2  2017-12-22  10:50:42     390      0.519231       0       0
# 3  2017-12-22  10:51:13     390      0.388462       0       0
# 4  2017-12-22  10:51:44     390      0.253846       0       0
#
#    Room_Occupancy_Count            Datetime    Temp  Light   Sound
# 0                     1 2017-12-22 10:49:41  80.595  218.0  0.3450
# 1                     1 2017-12-22 10:50:12  80.610  217.0  1.0550
# 2                     1 2017-12-22 10:50:42  80.610  218.0  0.6350
# 3                     1 2017-12-22 10:51:13  80.670  218.0  0.6325
# 4                     1 2017-12-22 10:51:44  80.670  219.0  0.3150

# %% [markdown]
# Now, we will rename and reorder a few columns before moving forward.

# %%
# columns to rename
renaming = {'S5_CO2': 'CO2', 
            'S5_CO2_Slope': 'CO2_Slope', 
            'S6_PIR': 'PIR_S1', 
            'S7_PIR': 'PIR_S2',}

# rename columns in existing dataframe
df = df.rename(renaming, axis=1)

# reorder columns in existing dataframe
df = df[['Datetime', 'Date', 'Time', 'Temp', 'Light', 'Sound', 'CO2', 'CO2_Slope', 'PIR_S1', 'PIR_S2', 'Room_Occupancy_Count']]

# view dataframe
df.head()
# Out:
#              Datetime        Date      Time    Temp  Light   Sound  CO2  \
# 0 2017-12-22 10:49:41  2017-12-22  10:49:41  80.595  218.0  0.3450  390
# 1 2017-12-22 10:50:12  2017-12-22  10:50:12  80.610  217.0  1.0550  390
# 2 2017-12-22 10:50:42  2017-12-22  10:50:42  80.610  218.0  0.6350  390
# 3 2017-12-22 10:51:13  2017-12-22  10:51:13  80.670  218.0  0.6325  390
# 4 2017-12-22 10:51:44  2017-12-22  10:51:44  80.670  219.0  0.3150  390
#
#    CO2_Slope  PIR_S1  PIR_S2  Room_Occupancy_Count
# 0   0.769231       0       0                     1
# 1   0.646154       0       0                     1
# 2   0.519231       0       0                     1
# 3   0.388462       0       0                     1
# 4   0.253846       0       0                     1

# %%
# describe dataframe
df.describe(datetime_is_numeric = True)
# Out:
#                             Datetime          Temp         Light  \
# count                          10129  10129.000000  10129.000000
# mean   2017-12-27 20:27:23.034554112     82.495223     89.014908
# min              2017-12-22 10:49:41     80.595000      0.000000
# 25%              2017-12-23 09:14:33     81.442500      0.000000
# 50%              2017-12-24 07:06:45     82.152500      0.000000
# 75%              2017-12-26 04:58:18     83.007500     92.000000
# max              2018-01-11 09:00:09     87.370000    720.250000
# std                              NaN      1.359938    166.377263
#
#               Sound           CO2     CO2_Slope        PIR_S1        PIR_S2  \
# count  10129.000000  10129.000000  10129.000000  10129.000000  10129.000000
# mean       0.472323    460.860401     -0.004830      0.090137      0.079574
# min        0.165000    345.000000     -6.296154      0.000000      0.000000
# 25%        0.195000    355.000000     -0.046154      0.000000      0.000000
# 50%        0.205000    360.000000      0.000000      0.000000      0.000000
# 75%        0.225000    465.000000      0.000000      0.000000      0.000000
# max       11.380000   1270.000000      8.980769      1.000000      1.000000
# std        0.856572    199.964940      1.164990      0.286392      0.270645
#
#        Room_Occupancy_Count
# count          10129.000000
# mean               0.398559
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max                3.000000
# std                0.893633

# %% [markdown]
# No further cleaning appears to be necessary for this dataset.

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# Let's create some visualizations to get a better understanding of the dataset and distribution of data.  We will start with histograms, boxplots, and violinplots.

# %%
#customize plots and show map denisty
g = sns.pairplot(df, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")

# %%
# create histograms for each feature
fig, axs = plt.subplots(4, 2, figsize=(10, 20))

sns.histplot(data=df, x='Temp', kde=True, ax=axs[0, 0])
sns.histplot(data=df, x='Light', kde=True, ax=axs[0, 1])
sns.histplot(data=df, x='Sound', kde=True, ax=axs[1, 0])
sns.histplot(data=df, x='CO2', kde=True, ax=axs[1, 1])
sns.histplot(data=df, x='CO2_Slope', kde=True, ax=axs[2, 0])
sns.histplot(data=df, x='PIR_S1', kde=True, ax=axs[2, 1])
sns.histplot(data=df, x='PIR_S2', kde=True, ax=axs[3, 0])
sns.histplot(data=df, x='Room_Occupancy_Count', kde=True, ax=axs[3, 1])

plt.show()

# %%
# create boxplots for each feature
fig, axs = plt.subplots(4, 2, figsize=(10, 20))

sns.boxplot(data=df, x='Temp', width=.3, linewidth=2, fliersize=5, ax=axs[0, 0])
sns.boxplot(data=df, x='Light', width=.3, linewidth=2, fliersize=5, ax=axs[0, 1])
sns.boxplot(data=df, x='Sound', width=.3, linewidth=2, fliersize=5, ax=axs[1, 0])
sns.boxplot(data=df, x='CO2', width=.3, linewidth=2, fliersize=5, ax=axs[1, 1])
sns.boxplot(data=df, x='CO2_Slope', width=.3, linewidth=2, fliersize=5, ax=axs[2, 0])
sns.boxplot(data=df, x='PIR_S1', width=.3, linewidth=2, fliersize=5, ax=axs[2, 1])
sns.boxplot(data=df, x='PIR_S2', width=.3, linewidth=2, fliersize=5, ax=axs[3, 0])
sns.boxplot(data=df, x='Room_Occupancy_Count', width=.3, linewidth=2, fliersize=5, ax=axs[3, 1])

plt.show()

# %% [markdown]
# Remove all outliers using z-sxore method. All z-score > 3 will be removed from a data set

# %%
# create violinplots for each feature
fig, axs = plt.subplots(4, 2, figsize=(10, 20))

sns.violinplot(data=df, x='Temp', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[0, 0])
sns.violinplot(data=df, x='Light', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[0, 1])
sns.violinplot(data=df, x='Sound', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[1, 0])
sns.violinplot(data=df, x='CO2', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[1, 1])
sns.violinplot(data=df, x='CO2_Slope', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[2, 0])
sns.violinplot(data=df, x='PIR_S1', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[2, 1])
sns.violinplot(data=df, x='PIR_S2', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[3, 0])
sns.violinplot(data=df, x='Room_Occupancy_Count', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[3, 1])

plt.show()

# %% [markdown]
# We can see that the Room Occupancy is empty (i.e., 0) for the majority of the time readings were collected.  This explains why most of our data does not appear to be normally distributed.  Most values are skewed to the left, indicating no or low sensor readings while rooms are vacant.  We will likely need to consider data tranformations and/or normalizations prior to training our machine learning models.

# %% [markdown]
# We will now calculate the skewness of each feature using the ```skew``` statistical function from the ```scipy.stats``` module.

# %% [markdown]
# #### Now, let's visualise key parameters of a data set in Tbaleau and performe some extra analysies

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1677435930984' style='position: relative'><noscript><a href='#'><img alt='Dashboard 3 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ro&#47;RoomOcupancy&#47;Dashboard3&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='RoomOcupancy&#47;Dashboard3' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ro&#47;RoomOcupancy&#47;Dashboard3&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1677435930984');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1677435930984' style='position: relative'><noscript><a href='#'><img alt='Dashboard 3 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ro&#47;RoomOcupancy&#47;Dashboard3&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='RoomOcupancy&#47;Dashboard3' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ro&#47;RoomOcupancy&#47;Dashboard3&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1677435930984');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# On this graph we make an interesting observation where as light increase decrease CO2 emisison and temperature slightly drops. However, it is not clear if Light and Temperature have strong co-relation or there are some other factors that affects Temperature.

# %%
# calculate the skewness
Temp_skewness = skew(df['Temp'])
Light_skewness = skew(df['Light'])
Sound_skewness = skew(df['Sound'])
CO2_skewness = skew(df['CO2'])
CO2_Slope_skewness = skew(df['CO2_Slope'])
PIR_S1_skewness = skew(df['PIR_S1'])
PIR_S2_skewness = skew(df['PIR_S2'])
Room_Occupancy_Count_skewness = skew(df['Room_Occupancy_Count'])

print(f"Skewness Temp = {Temp_skewness:.2f}")
print(f"Skewness Light = {Light_skewness:.2f}")
print(f"Skewness Sound = {Sound_skewness:.2f}")
print(f"Skewness CO2 = {CO2_skewness:.2f}")
print(f"Skewness CO2_Slope = {CO2_Slope_skewness:.2f}")
print(f"Skewness PIR_S1 = {PIR_S1_skewness:.2f}")
print(f"Skewness PIR_S2 = {PIR_S2_skewness:.2f}")
print(f"Skewness Room_Occupancy_Count = {Room_Occupancy_Count_skewness:.2f}")
# Out:
# Skewness Temp = 1.06
# Skewness Light = 2.17
# Skewness Sound = 4.69
# Skewness CO2 = 1.98
# Skewness CO2_Slope = 0.29
# Skewness PIR_S1 = 2.86
# Skewness PIR_S2 = 3.11
# Skewness Room_Occupancy_Count = 2.06

# %% [markdown]
# The results agree with our previous observation.  All features have a positvely-skewed data distribution, with the most skewed feature being Sound and the least skewed feature being CO2_Slope.

# %% [markdown]
# Finally, we will display a heatmap to look for the presence of multicollinearity in the features.

# %%
# find relationship between columns in form of a heat map
sns.heatmap(df.corr(), annot=True, fmt=".1f", mask=np.triu(df.corr()));

# %% [markdown]
# The highest correlations appear to be between Room_Occupancy_Count and Light (0.9), as well as between CO2 and Temp (0.8).

# %% [markdown]
# ## Machine Learning Tasks

# %% [markdown]
# ### Task 1a - Deep Learning LSTM Time Series Prediction for Room Occupancy Count

# %% [markdown]
# #### Load and prepare data

# %% [markdown]
# For our Deep Learning Long Short Term Memory (LSTM) Time Series prediction, we will begin by making a copy of our dataframe and splitting it into training and testing dataframes, using 80% for training and 20% for testing.

# %%
# create new copy of dataframe
df_lstm = df.copy()

# %%
# print shape of dataframe
print ('Shape of df_lstm is:', df_lstm.shape)
# Out:
# Shape of df_lstm is: (10129, 11)

# %%
# find location which splits df_lstm into 80% and 20%
loc_split = round((df_lstm.shape[0]*.80))

# create train_df using 80% of df_lstm
train_df = df_lstm.iloc[0:loc_split]

# create val_df using remaining 20% of df_lstm
val_df = df_lstm.iloc[loc_split:]

# reset validation dataframe index for cleanliness
val_df = val_df.reset_index()

# %%
# print shape of training and testing dataframes
print ('Shape of train_df is:', train_df.shape)
print ('Shape of val_df is:', val_df.shape)
# Out:
# Shape of train_df is: (8103, 11)
# Shape of val_df is: (2026, 12)

# %% [markdown]
# We can see that the shapes of our training and testing dataframes reflect the 80% and 20% split.  Let's now review our training dataframe.

# %%
# describe dataframe
train_df.describe(datetime_is_numeric = True)
# Out:
#                             Datetime         Temp        Light        Sound  \
# count                           8103  8103.000000  8103.000000  8103.000000
# mean   2017-12-24 07:29:07.647908352    82.594069   102.635073     0.508691
# min              2017-12-22 10:49:41    80.595000     0.000000     0.165000
# 25%       2017-12-23 04:51:51.500000    81.522500     0.000000     0.195000
# 50%              2017-12-23 22:21:52    82.242500     0.000000     0.207500
# 75%              2017-12-25 15:51:44    83.165000   120.125000     0.225000
# max              2018-01-10 15:34:59    87.370000   720.250000    11.380000
# std                              NaN     1.403560   174.548592     0.925703
#
#                CO2    CO2_Slope       PIR_S1       PIR_S2  \
# count  8103.000000  8103.000000  8103.000000  8103.000000
# mean    469.516846    -0.003256     0.091571     0.075034
# min     350.000000    -6.296154     0.000000     0.000000
# 25%     355.000000    -0.046154     0.000000     0.000000
# 50%     360.000000     0.000000     0.000000     0.000000
# 75%     485.000000     0.026923     0.000000     0.000000
# max    1270.000000     8.980769     1.000000     1.000000
# std     209.646787     1.199047     0.288437     0.263462
#
#        Room_Occupancy_Count
# count           8103.000000
# mean               0.407874
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max                3.000000
# std                0.884532

# %% [markdown]
# We can see that the numeric features are not on similar scales.  Let's normalize using the ```MinMaxScaler``` class from ```sklearn```.  We will omit any non-numeric columns from scaling, as well as Datetime and the PIR_S1 and PIR_S2 sensors since they hold binary values.  We will also avoid scaling our output feature of Room_Occupancy_Count.

# %% [markdown]
# # MinMax normalization (from 0 to 1)
#
# # select columns to normalize, exclude non-numeric, Datetime, PIR sensors, and output feature
# cols_normalize = train_df.columns.difference(['Date', 'Time', 'Datetime', 'PIR_S1', 'PIR_S2', 'Room_Occupancy_Count'])
#
# # scale selected columns between 0 and 1
# min_max_scaler = preprocessing.MinMaxScaler()
# norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]),
#                              columns=cols_normalize,
#                              index=train_df.index)
#
# # recombine scaled columns with the training dataframe
# join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
# train_df = join_df.reindex(columns = train_df.columns)
#
# # print dataframe head
# train_df.head()

# %%
# MinMax normalization (from 0 to 1)

# select columns to normalize, exclude non-numeric, Datetime, PIR sensors, and output feature
cols_normalize = train_df.columns.difference(['Date', 'Time', 'Datetime', 'Room_Occupancy_Count'])

# scale selected columns between 0 and 1
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)

# recombine scaled columns with the training dataframe
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

# print dataframe head
train_df.head()
# Out:
#              Datetime        Date      Time      Temp     Light     Sound  \
# 0 2017-12-22 10:49:41  2017-12-22  10:49:41  0.000000  0.302673  0.016050
# 1 2017-12-22 10:50:12  2017-12-22  10:50:12  0.002214  0.301284  0.079358
# 2 2017-12-22 10:50:42  2017-12-22  10:50:42  0.002214  0.302673  0.041908
# 3 2017-12-22 10:51:13  2017-12-22  10:51:13  0.011070  0.302673  0.041685
# 4 2017-12-22 10:51:44  2017-12-22  10:51:44  0.011070  0.304061  0.013375
#
#         CO2  CO2_Slope  PIR_S1  PIR_S2  Room_Occupancy_Count
# 0  0.043478   0.462487     0.0     0.0                     1
# 1  0.043478   0.454431     0.0     0.0                     1
# 2  0.043478   0.446123     0.0     0.0                     1
# 3  0.043478   0.437563     0.0     0.0                     1
# 4  0.043478   0.428751     0.0     0.0                     1

# %%
# describe dataframe
train_df.describe(datetime_is_numeric = True)
# Out:
#                             Datetime         Temp        Light        Sound  \
# count                           8103  8103.000000  8103.000000  8103.000000
# mean   2017-12-24 07:29:07.647908352     0.295066     0.142499     0.030646
# min              2017-12-22 10:49:41     0.000000     0.000000     0.000000
# 25%       2017-12-23 04:51:51.500000     0.136900     0.000000     0.002675
# 50%              2017-12-23 22:21:52     0.243173     0.000000     0.003790
# 75%              2017-12-25 15:51:44     0.379336     0.166782     0.005350
# max              2018-01-10 15:34:59     1.000000     1.000000     1.000000
# std                              NaN     0.207168     0.242344     0.082542
#
#                CO2    CO2_Slope       PIR_S1       PIR_S2  \
# count  8103.000000  8103.000000  8103.000000  8103.000000
# mean      0.129910     0.411922     0.091571     0.075034
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.005435     0.409114     0.000000     0.000000
# 50%       0.010870     0.412135     0.000000     0.000000
# 75%       0.146739     0.413897     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000
# std       0.227877     0.078487     0.288437     0.263462
#
#        Room_Occupancy_Count
# count           8103.000000
# mean               0.407874
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max                3.000000
# std                0.884532

# %% [markdown]
# All of our sensor colums now show values between 0 and 1, as seen by looking at the min and max values of each.

# %% [markdown]
# Before building our model, we will create a nested list structure for the training data, using a sequence of Temperature readings as the input and the Room Occupancy Count at our prediction horizon as the expected output.

# %%
# define sequence length and prediction horizon
seq_length = 25
ph = 1

# pick the feature columns 
feat_cols = ['Temp']

# create nested list structure
seq_arrays = []
seq_labs = []

# create list of sequence length temperature readings
rlen = len(train_df) - seq_length - ph
for start in range(0, rlen):
    seq_arrays.append(train_df[feat_cols].iloc[start:start+seq_length].to_numpy())
    seq_labs.append([train_df['Room_Occupancy_Count'].iloc[start:start+seq_length+ph].to_numpy()[-1]])
    
#convert to numpy arrays and floats to appease keras/tensorflow        
seq_arrays = np.array(seq_arrays, dtype = object).astype(np.float32)
seq_labs = np.array(seq_labs, dtype = object).astype(np.float32)

# %%
# assert statements to verify we have our expected array shapes
assert(seq_arrays.shape == (len(train_df)-seq_length-ph, seq_length, len(feat_cols)))
assert(seq_labs.shape == (len(train_df)-seq_length-ph, 1))

# %%
# print shape of sequence arrays and sequence labels
print ('Shape of seq_arrays is:', seq_arrays.shape)
print ('Shape of seq_labs is:', seq_labs.shape)
# Out:
# Shape of seq_arrays is: (8077, 25, 1)
# Shape of seq_labs is: (8077, 1)

# %% [markdown]
# Our sequence arrays are the shapes we expect.  They both have 8077 instances, and the seq_arrays shape reflects the seq_length we defined earlier.

# %% [markdown]
# #### Model Training

# %% [markdown]
# We will now build our Deep Learning Learning LSTM Time Series Prediction model.  This will be a sequential model with two LSTM layers, using a linear activation function and including dropout to prevent overtraining.

# %%
# define path to save model
model_path = 'LSTM_model1.h5'

# build the network
nb_features = seq_arrays.shape[2]
nb_out = seq_labs.shape[1]

# create sequential model object
model = Sequential()

#add first LSTM layer
model.add(LSTM(
         input_shape=(seq_length, nb_features),
         units=5, 
         return_sequences=True))
model.add(Dropout(0.2)) 

# add second LSTM layer
model.add(LSTM(
          units=3,
          return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=nb_out))
model.add(Activation('linear'))
optimizer = keras.optimizers.Adam(learning_rate = 0.005)
model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mse'])

# print model summary
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 25, 5)             140
#
#  dropout_4 (Dropout)         (None, 25, 5)             0
#
#  lstm_5 (LSTM)               (None, 3)                 108
#
#  dropout_5 (Dropout)         (None, 3)                 0
#
#  dense_2 (Dense)             (None, 1)                 4
#
#  activation_2 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 252
# Trainable params: 252
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# For our LSTM model, we can see that the LSTM and Dropout output shapes align with the hidden units we defined for each layer.  Our dense layer outputs one value, which is our prediction for Room Occupancy Count.  To tune the model, we decided to set a low value for the model's learning rate.  Additionally, we will adjust batch size while fitting the model, as well as the patience argument for early stopping.  In our experimentation with tuning, we find that allowing for additional epochs before stopping results in a more accurate model.  Let's now fit our model and plot the resulting Mean Squared Error (MSE) and loss.

# %%
# fit the model
history = model.fit(seq_arrays, seq_labs, epochs=100, batch_size=125, validation_split=0.05, verbose=2,
          callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=0, mode='min'),
                       keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
          )

# list all data in history
print(history.history.keys())
# Out:
# Epoch 1/100
# 62/62 - 9s - loss: 0.5687 - mse: 0.5687 - val_loss: 0.3607 - val_mse: 0.3607 - 9s/epoch - 144ms/step
# Epoch 2/100
# 62/62 - 2s - loss: 0.4274 - mse: 0.4274 - val_loss: 0.3570 - val_mse: 0.3570 - 2s/epoch - 25ms/step
# Epoch 3/100
# 62/62 - 1s - loss: 0.4096 - mse: 0.4096 - val_loss: 0.3525 - val_mse: 0.3525 - 1s/epoch - 21ms/step
# Epoch 4/100
# 62/62 - 1s - loss: 0.3945 - mse: 0.3945 - val_loss: 0.3502 - val_mse: 0.3502 - 1s/epoch - 17ms/step
# Epoch 5/100
# 62/62 - 1s - loss: 0.3933 - mse: 0.3933 - val_loss: 0.3492 - val_mse: 0.3492 - 1s/epoch - 17ms/step
# Epoch 6/100
# 62/62 - 1s - loss: 0.3931 - mse: 0.3931 - val_loss: 0.3541 - val_mse: 0.3541 - 1s/epoch - 18ms/step
# Epoch 7/100
# 62/62 - 1s - loss: 0.3776 - mse: 0.3776 - val_loss: 0.3508 - val_mse: 0.3508 - 1s/epoch - 19ms/step
# Epoch 8/100
# 62/62 - 1s - loss: 0.3702 - mse: 0.3702 - val_loss: 0.3211 - val_mse: 0.3211 - 1s/epoch - 17ms/step
# Epoch 9/100
# 62/62 - 1s - loss: 0.3705 - mse: 0.3705 - val_loss: 0.3495 - val_mse: 0.3495 - 997ms/epoch - 16ms/step
# Epoch 10/100
# 62/62 - 1s - loss: 0.3582 - mse: 0.3582 - val_loss: 0.3731 - val_mse: 0.3731 - 1s/epoch - 17ms/step
# Epoch 11/100
# 62/62 - 1s - loss: 0.3376 - mse: 0.3376 - val_loss: 0.3558 - val_mse: 0.3558 - 1s/epoch - 19ms/step
# Epoch 12/100
# 62/62 - 1s - loss: 0.3324 - mse: 0.3324 - val_loss: 0.3709 - val_mse: 0.3709 - 1s/epoch - 19ms/step
# Epoch 13/100
# 62/62 - 1s - loss: 0.3099 - mse: 0.3099 - val_loss: 0.3552 - val_mse: 0.3552 - 1s/epoch - 18ms/step
# Epoch 14/100
# 62/62 - 1s - loss: 0.2926 - mse: 0.2926 - val_loss: 0.3416 - val_mse: 0.3416 - 1s/epoch - 17ms/step
# Epoch 15/100
# 62/62 - 1s - loss: 0.2905 - mse: 0.2905 - val_loss: 0.3076 - val_mse: 0.3076 - 1s/epoch - 21ms/step
# Epoch 16/100
# 62/62 - 1s - loss: 0.3026 - mse: 0.3026 - val_loss: 0.2662 - val_mse: 0.2662 - 1s/epoch - 19ms/step
# Epoch 17/100
# 62/62 - 1s - loss: 0.2864 - mse: 0.2864 - val_loss: 0.3404 - val_mse: 0.3404 - 1s/epoch - 17ms/step
# Epoch 18/100
# 62/62 - 1s - loss: 0.2720 - mse: 0.2720 - val_loss: 0.3033 - val_mse: 0.3033 - 1s/epoch - 17ms/step
# Epoch 19/100
# 62/62 - 1s - loss: 0.2789 - mse: 0.2789 - val_loss: 0.2963 - val_mse: 0.2963 - 1s/epoch - 17ms/step
# Epoch 20/100
# 62/62 - 1s - loss: 0.2615 - mse: 0.2615 - val_loss: 0.2976 - val_mse: 0.2976 - 1s/epoch - 17ms/step
# Epoch 21/100
# 62/62 - 1s - loss: 0.2747 - mse: 0.2747 - val_loss: 0.2672 - val_mse: 0.2672 - 1s/epoch - 17ms/step
# Epoch 22/100
# 62/62 - 1s - loss: 0.2809 - mse: 0.2809 - val_loss: 0.2608 - val_mse: 0.2608 - 1s/epoch - 17ms/step
# Epoch 23/100
# 62/62 - 1s - loss: 0.2654 - mse: 0.2654 - val_loss: 0.2789 - val_mse: 0.2789 - 1s/epoch - 19ms/step
# Epoch 24/100
# 62/62 - 1s - loss: 0.2629 - mse: 0.2629 - val_loss: 0.2218 - val_mse: 0.2218 - 1s/epoch - 18ms/step
# Epoch 25/100
# 62/62 - 1s - loss: 0.2560 - mse: 0.2560 - val_loss: 0.2394 - val_mse: 0.2394 - 1s/epoch - 19ms/step
# Epoch 26/100
# 62/62 - 1s - loss: 0.2618 - mse: 0.2618 - val_loss: 0.2338 - val_mse: 0.2338 - 1s/epoch - 18ms/step
# Epoch 27/100
# 62/62 - 1s - loss: 0.2467 - mse: 0.2467 - val_loss: 0.2205 - val_mse: 0.2205 - 1s/epoch - 19ms/step
# Epoch 28/100
# 62/62 - 1s - loss: 0.2700 - mse: 0.2700 - val_loss: 0.2623 - val_mse: 0.2623 - 1s/epoch - 20ms/step
# Epoch 29/100
# 62/62 - 1s - loss: 0.2590 - mse: 0.2590 - val_loss: 0.2129 - val_mse: 0.2129 - 1s/epoch - 22ms/step
# Epoch 30/100
# 62/62 - 1s - loss: 0.2612 - mse: 0.2612 - val_loss: 0.2501 - val_mse: 0.2501 - 1s/epoch - 21ms/step
# Epoch 31/100
# 62/62 - 2s - loss: 0.2570 - mse: 0.2570 - val_loss: 0.1787 - val_mse: 0.1787 - 2s/epoch - 27ms/step
# Epoch 32/100
# 62/62 - 2s - loss: 0.2542 - mse: 0.2542 - val_loss: 0.1684 - val_mse: 0.1684 - 2s/epoch - 29ms/step
# Epoch 33/100
# 62/62 - 2s - loss: 0.2356 - mse: 0.2356 - val_loss: 0.2049 - val_mse: 0.2049 - 2s/epoch - 26ms/step
# Epoch 34/100
# 62/62 - 1s - loss: 0.2592 - mse: 0.2592 - val_loss: 0.1662 - val_mse: 0.1662 - 1s/epoch - 23ms/step
# Epoch 35/100
# 62/62 - 2s - loss: 0.2389 - mse: 0.2389 - val_loss: 0.1425 - val_mse: 0.1425 - 2s/epoch - 27ms/step
# Epoch 36/100
# 62/62 - 1s - loss: 0.2447 - mse: 0.2447 - val_loss: 0.1514 - val_mse: 0.1514 - 1s/epoch - 22ms/step
# Epoch 37/100
# 62/62 - 1s - loss: 0.2286 - mse: 0.2286 - val_loss: 0.1460 - val_mse: 0.1460 - 1s/epoch - 21ms/step
# Epoch 38/100
# 62/62 - 1s - loss: 0.2488 - mse: 0.2488 - val_loss: 0.2030 - val_mse: 0.2030 - 1s/epoch - 18ms/step
# Epoch 39/100
# 62/62 - 1s - loss: 0.2315 - mse: 0.2315 - val_loss: 0.1496 - val_mse: 0.1496 - 1s/epoch - 19ms/step
# Epoch 40/100
# 62/62 - 1s - loss: 0.2405 - mse: 0.2405 - val_loss: 0.1331 - val_mse: 0.1331 - 1s/epoch - 20ms/step
# Epoch 41/100
# 62/62 - 1s - loss: 0.2253 - mse: 0.2253 - val_loss: 0.1247 - val_mse: 0.1247 - 1s/epoch - 22ms/step
# Epoch 42/100
# 62/62 - 1s - loss: 0.2488 - mse: 0.2488 - val_loss: 0.1387 - val_mse: 0.1387 - 1s/epoch - 22ms/step
# Epoch 43/100
# 62/62 - 1s - loss: 0.2356 - mse: 0.2356 - val_loss: 0.1422 - val_mse: 0.1422 - 1s/epoch - 21ms/step
# Epoch 44/100
# 62/62 - 1s - loss: 0.2269 - mse: 0.2269 - val_loss: 0.1727 - val_mse: 0.1727 - 1s/epoch - 19ms/step
# Epoch 45/100
# 62/62 - 1s - loss: 0.2291 - mse: 0.2291 - val_loss: 0.1441 - val_mse: 0.1441 - 1s/epoch - 18ms/step
# Epoch 46/100
# 62/62 - 1s - loss: 0.2224 - mse: 0.2224 - val_loss: 0.1113 - val_mse: 0.1113 - 1s/epoch - 19ms/step
# Epoch 47/100
# 62/62 - 1s - loss: 0.2160 - mse: 0.2160 - val_loss: 0.1380 - val_mse: 0.1380 - 1s/epoch - 19ms/step
# Epoch 48/100
# 62/62 - 1s - loss: 0.2453 - mse: 0.2453 - val_loss: 0.1741 - val_mse: 0.1741 - 1s/epoch - 19ms/step
# Epoch 49/100
# 62/62 - 1s - loss: 0.2295 - mse: 0.2295 - val_loss: 0.1004 - val_mse: 0.1004 - 1s/epoch - 20ms/step
# Epoch 50/100
# 62/62 - 1s - loss: 0.2249 - mse: 0.2249 - val_loss: 0.1307 - val_mse: 0.1307 - 1s/epoch - 22ms/step
# Epoch 51/100
# 62/62 - 1s - loss: 0.2273 - mse: 0.2273 - val_loss: 0.1492 - val_mse: 0.1492 - 1s/epoch - 20ms/step
# Epoch 52/100
# 62/62 - 1s - loss: 0.2195 - mse: 0.2195 - val_loss: 0.1137 - val_mse: 0.1137 - 1s/epoch - 21ms/step
# Epoch 53/100
# 62/62 - 1s - loss: 0.2267 - mse: 0.2267 - val_loss: 0.1049 - val_mse: 0.1049 - 1s/epoch - 21ms/step
# Epoch 54/100
# 62/62 - 1s - loss: 0.2167 - mse: 0.2167 - val_loss: 0.1099 - val_mse: 0.1099 - 1s/epoch - 19ms/step
# Epoch 55/100
# 62/62 - 1s - loss: 0.2073 - mse: 0.2073 - val_loss: 0.1052 - val_mse: 0.1052 - 1s/epoch - 20ms/step
# Epoch 56/100
# 62/62 - 1s - loss: 0.2215 - mse: 0.2215 - val_loss: 0.1428 - val_mse: 0.1428 - 1s/epoch - 19ms/step
# Epoch 57/100
# 62/62 - 1s - loss: 0.2193 - mse: 0.2193 - val_loss: 0.0977 - val_mse: 0.0977 - 1s/epoch - 17ms/step
# Epoch 58/100
# 62/62 - 1s - loss: 0.2142 - mse: 0.2142 - val_loss: 0.1225 - val_mse: 0.1225 - 1s/epoch - 17ms/step
# Epoch 59/100
# 62/62 - 1s - loss: 0.2215 - mse: 0.2215 - val_loss: 0.1202 - val_mse: 0.1202 - 1s/epoch - 18ms/step
# Epoch 60/100
# 62/62 - 1s - loss: 0.2260 - mse: 0.2260 - val_loss: 0.1217 - val_mse: 0.1217 - 1s/epoch - 19ms/step
# Epoch 61/100
# 62/62 - 1s - loss: 0.2425 - mse: 0.2425 - val_loss: 0.0990 - val_mse: 0.0990 - 1s/epoch - 17ms/step
# Epoch 62/100
# 62/62 - 1s - loss: 0.2161 - mse: 0.2161 - val_loss: 0.1064 - val_mse: 0.1064 - 1s/epoch - 18ms/step
# Epoch 63/100
# 62/62 - 1s - loss: 0.2090 - mse: 0.2090 - val_loss: 0.1285 - val_mse: 0.1285 - 991ms/epoch - 16ms/step
# Epoch 64/100
# 62/62 - 1s - loss: 0.2163 - mse: 0.2163 - val_loss: 0.1246 - val_mse: 0.1246 - 1s/epoch - 17ms/step
# Epoch 65/100
# 62/62 - 1s - loss: 0.2249 - mse: 0.2249 - val_loss: 0.1042 - val_mse: 0.1042 - 1s/epoch - 18ms/step
# Epoch 66/100
# 62/62 - 1s - loss: 0.2169 - mse: 0.2169 - val_loss: 0.1366 - val_mse: 0.1366 - 1s/epoch - 20ms/step
# Epoch 67/100
# 62/62 - 1s - loss: 0.2187 - mse: 0.2187 - val_loss: 0.1196 - val_mse: 0.1196 - 1s/epoch - 17ms/step
# Epoch 68/100
# 62/62 - 1s - loss: 0.2166 - mse: 0.2166 - val_loss: 0.0841 - val_mse: 0.0841 - 1s/epoch - 18ms/step
# Epoch 69/100
# 62/62 - 1s - loss: 0.2199 - mse: 0.2199 - val_loss: 0.1036 - val_mse: 0.1036 - 1s/epoch - 17ms/step
# Epoch 70/100
# 62/62 - 1s - loss: 0.2209 - mse: 0.2209 - val_loss: 0.0965 - val_mse: 0.0965 - 1s/epoch - 16ms/step
# Epoch 71/100
# 62/62 - 1s - loss: 0.2051 - mse: 0.2051 - val_loss: 0.0937 - val_mse: 0.0937 - 983ms/epoch - 16ms/step
# Epoch 72/100
# 62/62 - 1s - loss: 0.2225 - mse: 0.2225 - val_loss: 0.0950 - val_mse: 0.0950 - 949ms/epoch - 15ms/step
# Epoch 73/100
# 62/62 - 1s - loss: 0.2361 - mse: 0.2361 - val_loss: 0.0993 - val_mse: 0.0993 - 1s/epoch - 16ms/step
# Epoch 74/100
# 62/62 - 1s - loss: 0.2264 - mse: 0.2264 - val_loss: 0.1074 - val_mse: 0.1074 - 1s/epoch - 17ms/step
# Epoch 75/100
# 62/62 - 1s - loss: 0.2070 - mse: 0.2070 - val_loss: 0.0979 - val_mse: 0.0979 - 980ms/epoch - 16ms/step
# Epoch 76/100
# 62/62 - 1s - loss: 0.2206 - mse: 0.2206 - val_loss: 0.0939 - val_mse: 0.0939 - 1s/epoch - 16ms/step
# Epoch 77/100
# 62/62 - 1s - loss: 0.2141 - mse: 0.2141 - val_loss: 0.0964 - val_mse: 0.0964 - 1s/epoch - 17ms/step
# Epoch 78/100
# 62/62 - 1s - loss: 0.2480 - mse: 0.2480 - val_loss: 0.1025 - val_mse: 0.1025 - 1s/epoch - 18ms/step
# Epoch 79/100
# 62/62 - 1s - loss: 0.2133 - mse: 0.2133 - val_loss: 0.1045 - val_mse: 0.1045 - 1s/epoch - 17ms/step
# Epoch 80/100
# 62/62 - 1s - loss: 0.2078 - mse: 0.2078 - val_loss: 0.0972 - val_mse: 0.0972 - 1s/epoch - 19ms/step
# Epoch 81/100
# 62/62 - 1s - loss: 0.2190 - mse: 0.2190 - val_loss: 0.0828 - val_mse: 0.0828 - 1s/epoch - 21ms/step
# Epoch 82/100
# 62/62 - 1s - loss: 0.2095 - mse: 0.2095 - val_loss: 0.0925 - val_mse: 0.0925 - 1s/epoch - 22ms/step
# Epoch 83/100
# 62/62 - 1s - loss: 0.2027 - mse: 0.2027 - val_loss: 0.1119 - val_mse: 0.1119 - 1s/epoch - 23ms/step
# Epoch 84/100
# 62/62 - 1s - loss: 0.2213 - mse: 0.2213 - val_loss: 0.1061 - val_mse: 0.1061 - 1s/epoch - 17ms/step
# Epoch 85/100
# 62/62 - 1s - loss: 0.2153 - mse: 0.2153 - val_loss: 0.0992 - val_mse: 0.0992 - 983ms/epoch - 16ms/step
# Epoch 86/100
# 62/62 - 1s - loss: 0.2068 - mse: 0.2068 - val_loss: 0.0882 - val_mse: 0.0882 - 1s/epoch - 18ms/step
# Epoch 87/100
# 62/62 - 1s - loss: 0.2163 - mse: 0.2163 - val_loss: 0.1053 - val_mse: 0.1053 - 1s/epoch - 18ms/step
# Epoch 88/100
# 62/62 - 1s - loss: 0.2083 - mse: 0.2083 - val_loss: 0.0971 - val_mse: 0.0971 - 1s/epoch - 23ms/step
# Epoch 89/100
# 62/62 - 1s - loss: 0.2024 - mse: 0.2024 - val_loss: 0.0855 - val_mse: 0.0855 - 1s/epoch - 23ms/step
# Epoch 90/100
# 62/62 - 1s - loss: 0.2157 - mse: 0.2157 - val_loss: 0.0907 - val_mse: 0.0907 - 1s/epoch - 20ms/step
# Epoch 91/100
# 62/62 - 1s - loss: 0.2094 - mse: 0.2094 - val_loss: 0.0907 - val_mse: 0.0907 - 1s/epoch - 18ms/step
# Epoch 92/100
# 62/62 - 1s - loss: 0.2048 - mse: 0.2048 - val_loss: 0.0886 - val_mse: 0.0886 - 1s/epoch - 17ms/step
# Epoch 93/100
# 62/62 - 1s - loss: 0.2151 - mse: 0.2151 - val_loss: 0.0926 - val_mse: 0.0926 - 1s/epoch - 16ms/step
# Epoch 94/100
# 62/62 - 1s - loss: 0.2177 - mse: 0.2177 - val_loss: 0.0981 - val_mse: 0.0981 - 1s/epoch - 16ms/step
# Epoch 95/100
# 62/62 - 1s - loss: 0.2184 - mse: 0.2184 - val_loss: 0.0985 - val_mse: 0.0985 - 1s/epoch - 17ms/step
# Epoch 96/100
# 62/62 - 1s - loss: 0.2217 - mse: 0.2217 - val_loss: 0.0996 - val_mse: 0.0996 - 1s/epoch - 17ms/step
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
# summarize history for MSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('model MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("LSTM_mse1.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("LSTM_loss1.png")

# %% [markdown]
# We can see great performance of our LSTM model during training.  The model MSE and loss reduces significantly with both the training and testing data, we also do not see the testing data loss get higher than the training data loss once its loss initially drops below the loss amount for the training data.

# %% [markdown]
# #### Model Validation

# %% [markdown]
# In order to validate our model, we will create a simulated "production" dataset.  This will mimic a streaming dataset, so any data sequences less than our defined sequence length will be padded with zeroes to ensure the correct sequence length is used until the number of readings streamed equal the defined sequence length.

# %%
# create arrays for validation dataset inputs and output
val_arrays = []
val_labs = []

# create list of temperature readings starting with a minimum of two readings
rlen = len(val_df) - ph
for end in range(2, rlen):
    if (end < seq_length):
        val_arrays.append(val_df[feat_cols][0:end].to_numpy())
        val_labs.append(val_df['Room_Occupancy_Count'][end+ph])
    # add sequences of defined seq_length once we have enough readings
    else:
        val_arrays.append(val_df[feat_cols][end-seq_length:end].to_numpy())
        val_labs.append(val_df['Room_Occupancy_Count'][end+ph])

# use pad_sequences function on input sequences, specify np.float32 to appease keras/tensorflow
val_arrays = pad_sequences(val_arrays, maxlen = seq_length, dtype = np.float32)

#convert labels to numpy arrays and floats to appease keras/tensorflow
val_labs = np.array(val_labs, dtype = object).astype(np.float32)

# %% [markdown]
# We will now run the validation data through our LSTM model and visualize the performance.

# %%
scores_test = model.evaluate(val_arrays, val_labs, verbose=2)
print('\nMSE: {}'.format(scores_test[1]))

y_pred_test = model.predict(val_arrays)
y_pred_test2 = np.floor(y_pred_test) # round down to nearest integer
y_true_test = val_labs

test_set = pd.DataFrame(y_pred_test2)
test_set.to_csv('submit_test.csv', index = None)

# plot the predicted data vs. the actual data
# we will limit our plot to the last 2000 predictions for better visualization
fig_verify = plt.figure(figsize=(10, 5))
plt.plot(y_pred_test2[-2000:], label = 'Predicted Value')
plt.plot(y_true_test[-2000:], label = 'Actual Value')
plt.title('Room Occupancy Count Prediction - Last 2000 Points', fontsize=22, fontweight='bold')
plt.ylabel('value')
plt.xlabel('row')
plt.legend()
plt.show()
fig_verify.savefig("model_regression_verify.png")
# Out:
# 64/64 - 2s - loss: 9.9175 - mse: 9.9349 - 2s/epoch - 25ms/step
#
# MSE: 9.934935569763184
# 64/64 [==============================] - 1s 3ms/step

# %% [markdown]
# Our validation did not perform as well as our previous test data.  Unfortunately, we believe this is, in part, because of the lack of sufficient data.  The majority of our validation data has 0 for the true value of Room Occupancy Count.  We can take a look at the breakdown of our output feature's actual values.

# %%
# print output feature value counts for both the original dataframe and validation dataframe
print ('Original Dataframe:\n',(df_raw.groupby(['Room_Occupancy_Count'])['Room_Occupancy_Count'].count()))
print ('\nValidation Dataframe:\n',(val_df.groupby(['Room_Occupancy_Count'])['Room_Occupancy_Count'].count()))
# Out:
# Original Dataframe:
#  Room_Occupancy_Count
# 0    8228
# 1     459
# 2     748
# 3     694
# Name: Room_Occupancy_Count, dtype: int64
#
# Validation Dataframe:
#  Room_Occupancy_Count
# 0    1751
# 2      93
# 3     182
# Name: Room_Occupancy_Count, dtype: int64

# %% [markdown]
# We can see again see that the grand majority of output values are 0.  As noted during exploratory data analysis, the data was collected over a short timeframe of only seven days, including Christmas Eve and Christmas Day.  Presumably because of this, multiple days have 0 occupants recorded for the entire day.  For our validation dataset, we can see that there are no values of 1 occupant and only 275 values that were not 0, as compared to 1751 values which are 0.  We think our model would perform better with a larger dataset containing more occupancy activity.

# %% [markdown]
# ### Task 1b - Deep Learning Model Prediction for Room Occupancy Count

# %% [markdown]
# Below is another apporach for predicting room occupacy count using deep learning. We will start creating a Classification model for predicting the number occupancy. Here we will begin by making a copy of our dataframe and splitting it into training, test and validation.

# %% [markdown]
# #### Load and prepare data

# %%
df_dl = df.copy()

# %%
# Divide the data in to features - X and labels - y (Room_Occupancy_Count)

labels = df_dl.pop('Room_Occupancy_Count').values.astype('float32')
features = df_dl.iloc[:,3:].values.astype('float32') # All the sensor readings except for Room_Occupancy_count

# %%
# Divide the data into train set, validation set, and test set

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=.1) 
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=.1)

# %%
# Use MinMaxScaler to normalize the input data

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %%
# Change the labels dataset to one_hot. With one-hot, we convert each categorical value into a new categorical 
# column and assign a binary value of 1 or 0 to those columns. Here count values are one of - 0, 1, 2 or 3.

y_train, y_valid, y_test = to_categorical(y_train),to_categorical(y_valid), to_categorical(y_test)

# %%
# Check the shape of the data
print(X_train_scaled.shape,X_valid_scaled.shape,X_test_scaled.shape)
# Out:
# (8204, 7) (912, 7) (1013, 7)

# %% [markdown]
# #### Model Training

# %%
# half the learning rate when val_loss stop reduce during training
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                               patience=3,
                                                               verbose=0,
                                                               factor=.5,
                                                               min_lr=.00001)

# %%
model_class = tf.keras.Sequential([
    tf.keras.layers.Dense(128,activation='relu',input_shape=[7]),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(4,activation='softmax') # Output 4 units representing the Occupancy Number 0, 1, 2, 3
])

model_class.compile(loss='categorical_crossentropy',
             optimizer=tf.keras.optimizers.Adam(),
             metrics=['accuracy'])

print(model_class.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               1024
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 34,564
# Trainable params: 34,564
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model_class.fit(X_train_scaled,y_train,
                epochs=50,
                batch_size=32,
                validation_data=(X_valid_scaled,y_valid),
                callbacks=[learning_rate_reduction],
                verbose=1)

# list all data in history
print(history.history.keys())
# Out:
# Epoch 1/50
# 257/257 [==============================] - 2s 3ms/step - loss: 0.2978 - accuracy: 0.9057 - val_loss: 0.1035 - val_accuracy: 0.9594 - lr: 0.0010
# Epoch 2/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0896 - accuracy: 0.9726 - val_loss: 0.0441 - val_accuracy: 0.9901 - lr: 0.0010
# Epoch 3/50
# 257/257 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9843 - val_loss: 0.0405 - val_accuracy: 0.9825 - lr: 0.0010
# Epoch 4/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0428 - accuracy: 0.9860 - val_loss: 0.0405 - val_accuracy: 0.9890 - lr: 0.0010
# Epoch 5/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0358 - accuracy: 0.9871 - val_loss: 0.0294 - val_accuracy: 0.9901 - lr: 0.0010
# Epoch 6/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0327 - accuracy: 0.9879 - val_loss: 0.0270 - val_accuracy: 0.9901 - lr: 0.0010
# Epoch 7/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0295 - accuracy: 0.9894 - val_loss: 0.0389 - val_accuracy: 0.9901 - lr: 0.0010
# Epoch 8/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0312 - accuracy: 0.9884 - val_loss: 0.0284 - val_accuracy: 0.9912 - lr: 0.0010
# Epoch 9/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0283 - accuracy: 0.9895 - val_loss: 0.0330 - val_accuracy: 0.9879 - lr: 0.0010
# Epoch 10/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0256 - accuracy: 0.9899 - val_loss: 0.0227 - val_accuracy: 0.9934 - lr: 5.0000e-04
# Epoch 11/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0265 - accuracy: 0.9899 - val_loss: 0.0239 - val_accuracy: 0.9923 - lr: 5.0000e-04
# Epoch 12/50
# 257/257 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9898 - val_loss: 0.0287 - val_accuracy: 0.9890 - lr: 5.0000e-04
# Epoch 13/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0236 - accuracy: 0.9902 - val_loss: 0.0224 - val_accuracy: 0.9912 - lr: 5.0000e-04
# Epoch 14/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0231 - accuracy: 0.9904 - val_loss: 0.0247 - val_accuracy: 0.9923 - lr: 5.0000e-04
# Epoch 15/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0232 - accuracy: 0.9899 - val_loss: 0.0245 - val_accuracy: 0.9912 - lr: 5.0000e-04
# Epoch 16/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0228 - accuracy: 0.9911 - val_loss: 0.0216 - val_accuracy: 0.9934 - lr: 5.0000e-04
# Epoch 17/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0224 - accuracy: 0.9911 - val_loss: 0.0223 - val_accuracy: 0.9912 - lr: 5.0000e-04
# Epoch 18/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0225 - accuracy: 0.9909 - val_loss: 0.0206 - val_accuracy: 0.9945 - lr: 5.0000e-04
# Epoch 19/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0231 - accuracy: 0.9904 - val_loss: 0.0219 - val_accuracy: 0.9912 - lr: 5.0000e-04
# Epoch 20/50
# 257/257 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9894 - val_loss: 0.0204 - val_accuracy: 0.9923 - lr: 5.0000e-04
# Epoch 21/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0210 - accuracy: 0.9915 - val_loss: 0.0220 - val_accuracy: 0.9901 - lr: 5.0000e-04
# Epoch 22/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0212 - accuracy: 0.9915 - val_loss: 0.0227 - val_accuracy: 0.9934 - lr: 5.0000e-04
# Epoch 23/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0222 - accuracy: 0.9916 - val_loss: 0.0247 - val_accuracy: 0.9912 - lr: 5.0000e-04
# Epoch 24/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0206 - accuracy: 0.9910 - val_loss: 0.0211 - val_accuracy: 0.9934 - lr: 2.5000e-04
# Epoch 25/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0197 - accuracy: 0.9921 - val_loss: 0.0198 - val_accuracy: 0.9934 - lr: 2.5000e-04
# Epoch 26/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0190 - accuracy: 0.9923 - val_loss: 0.0198 - val_accuracy: 0.9934 - lr: 2.5000e-04
# Epoch 27/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0188 - accuracy: 0.9917 - val_loss: 0.0206 - val_accuracy: 0.9923 - lr: 2.5000e-04
# Epoch 28/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0191 - accuracy: 0.9916 - val_loss: 0.0222 - val_accuracy: 0.9901 - lr: 2.5000e-04
# Epoch 29/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.9920 - val_loss: 0.0200 - val_accuracy: 0.9923 - lr: 1.2500e-04
# Epoch 30/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0181 - accuracy: 0.9923 - val_loss: 0.0204 - val_accuracy: 0.9945 - lr: 1.2500e-04
# Epoch 31/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0177 - accuracy: 0.9921 - val_loss: 0.0195 - val_accuracy: 0.9923 - lr: 1.2500e-04
# Epoch 32/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0179 - accuracy: 0.9923 - val_loss: 0.0206 - val_accuracy: 0.9934 - lr: 1.2500e-04
# Epoch 33/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0174 - accuracy: 0.9926 - val_loss: 0.0213 - val_accuracy: 0.9934 - lr: 1.2500e-04
# Epoch 34/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0178 - accuracy: 0.9924 - val_loss: 0.0193 - val_accuracy: 0.9934 - lr: 1.2500e-04
# Epoch 35/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0176 - accuracy: 0.9923 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 1.2500e-04
# Epoch 36/50
# 257/257 [==============================] - 1s 3ms/step - loss: 0.0181 - accuracy: 0.9918 - val_loss: 0.0197 - val_accuracy: 0.9923 - lr: 1.2500e-04
# Epoch 37/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0172 - accuracy: 0.9920 - val_loss: 0.0205 - val_accuracy: 0.9923 - lr: 1.2500e-04
# Epoch 38/50
# 257/257 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9927 - val_loss: 0.0199 - val_accuracy: 0.9923 - lr: 6.2500e-05
# Epoch 39/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0170 - accuracy: 0.9924 - val_loss: 0.0199 - val_accuracy: 0.9923 - lr: 6.2500e-05
# Epoch 40/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0168 - accuracy: 0.9924 - val_loss: 0.0201 - val_accuracy: 0.9934 - lr: 6.2500e-05
# Epoch 41/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0167 - accuracy: 0.9929 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 3.1250e-05
# Epoch 42/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0166 - accuracy: 0.9927 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 3.1250e-05
# Epoch 43/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0166 - accuracy: 0.9928 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 3.1250e-05
# Epoch 44/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0165 - accuracy: 0.9926 - val_loss: 0.0195 - val_accuracy: 0.9923 - lr: 1.5625e-05
# Epoch 45/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9924 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 1.5625e-05
# Epoch 46/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9926 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 1.5625e-05
# Epoch 47/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9928 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 1.0000e-05
# Epoch 48/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0163 - accuracy: 0.9928 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 1.0000e-05
# Epoch 49/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9926 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 1.0000e-05
# Epoch 50/50
# 257/257 [==============================] - 1s 2ms/step - loss: 0.0164 - accuracy: 0.9922 - val_loss: 0.0196 - val_accuracy: 0.9923 - lr: 1.0000e-05
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# summarize history for Accuracy
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_accuracy.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_loss.png")

# training metrics
scores = model_class.evaluate(X_train_scaled, y_train, verbose=1, batch_size=32)
print('Accuracy: {}'.format(scores[1]))

# make predictions and compute confusion matrix
y_pred = model_class.predict(X_train_scaled,verbose=1, batch_size=32)
y_pred = np.argmax(y_pred, axis=1)
# y_true = y_train
y_true = np.argmax(y_train, axis=1)

test_set = pd.DataFrame(y_pred)
test_set.to_csv('binary_submit_train.csv', index = None)

print('Confusion matrix\n- x-axis is true labels.\n- y-axis is predicted labels')
cm = confusion_matrix(y_true, y_pred)
print(cm)

# compute precision and recall
precision = precision_score(y_true, y_pred, average='micro')
#recall = recall_score(y_true, y_pred.round, average='micro')
#print( 'precision = ', precision, '\n', 'recall = ', recall)
print( 'precision = ', precision, '\n')
# Out:
# 257/257 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9924
# Accuracy: 0.9924427270889282
# 257/257 [==============================] - 0s 1ms/step
# Confusion matrix
# - x-axis is true labels.
# - y-axis is predicted labels
# [[6617    0    0    0]
#  [   0  382    2    0]
#  [   0    0  581   45]
#  [   1    0   14  562]]
# precision =  0.992442710872745

# %% [markdown]
# #### Model Validation

# %%
def process_data(data):
    return np.array(tf.argmax(data,axis=1),dtype='float32')

y_pred = process_data(model_class.predict(X_test_scaled))

print(classification_report(tf.argmax(y_test,axis=1),y_pred))
# Out:
# 32/32 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       844
#            1       1.00      1.00      1.00        36
#            2       0.91      0.98      0.95        62
#            3       0.99      0.94      0.96        71
#
#     accuracy                           0.99      1013
#    macro avg       0.97      0.98      0.98      1013
# weighted avg       0.99      0.99      0.99      1013

# %%
cf_matrix = confusion_matrix(tf.argmax(y_test, axis=1),y_pred)
sns.set_theme(style='whitegrid',rc={'figure.figsize':(12,5)})

fig, axs = plt.subplots(1,2)

# Number count
ax1 = sns.heatmap(cf_matrix,annot=True,cmap='Reds', ax=axs[0], fmt="g")
ax1.set_title('Room Occupancy Prediction Count')

# Percentage
ax2 = sns.heatmap(cf_matrix/np.sum(cf_matrix),annot=True,fmt='.2%',cmap='Blues',ax=axs[1])
ax2.set_title('Room Occupancy Prediction in %');

# %% [markdown]
# ### Task 2 - Multiple Regression Model Prediction for CO2

# %% [markdown]
# For our Multiple Regression prediction, we will first determine which features we would like to include in the model, and we will make sure there isn't significant multicollinearity present.

# %% [markdown]
# #### Load and prepare data

# %%
# create new dataframe with raw data
df_mr = df.copy()

# %%
#convert datetime to epoch/unix time. In this dataset, readings are done every 30 seconds.
df_mr['time'] = (pd.to_datetime(df_mr.Datetime)-pd.to_datetime('1970-01-01')).dt.total_seconds()

# %% [markdown]
# The goal is to predict the CO2 (ppm) by leveraging Time and Temperature. First we will create the x (time, Temp) and y (CO2) training variables, and then define the model parameters.

# %%
#add to the x-variables in our dataset
x_variables = ['time', 'Temp']
ts = df_mr[x_variables]
ys = pd.DataFrame(df_mr.CO2)
#ys = pd.DataFrame(df_mr.Light)

ph = 0.5*60 # 0.5 minutes or 30 seconds
###############################################################
#WE NEED TO CONVERT OUR PREDICTIVE HORIZON INTO A NUMBER OF
#TIME STEPS FOR INDEXING, BASED ON THE RESOLUTION OF OUR DATA.
#IN THIS CASE OUR DATA IS COLLECTED EVERY 30 seconds
##############################################################
ph_index = round(ph/30)
mu = 0.9

n_s = 3000

# Arrays to hold predicted values
tp_pred = np.zeros(n_s-1)
yp_pred = np.zeros(n_s-1)

# %% [markdown]
# #### Model Training

# %% [markdown]
# Using LinearRegression, predict the CO2 for the dataset. These predictions are stored in tp_pred and yp_pred lists.

# %%
# At every iteration of the for loop a new data sample is acquired
# start with 2 leading datapoints

for i in range(2, n_s+1):
    
    # get x and y data
    # subtract 1 so that we don't give the model access to future data
    ts_tmp = ts[0:i-1] 
    
    # Use the value at the predictive horizon index as the predicted 
    # value for training
    ys_tmp = ys[ph_index-1:ph_index-1+i-1]
    
    ns = len(ys_tmp)
    
    weights = np.ones(ns)*mu
    
    for k in range(ns):
        weights[k] = weights[k]**k # weights are downweighted as per timestamp away from prediction
        
    weights = np.flip(weights, 0)
    
    #perform linear regression on "available" data using the mu-adjusted weights
    lm_tmp = LinearRegression()
    model_tmp = lm_tmp.fit(ts_tmp, ys_tmp, sample_weight=weights)
    
    #store model coefficients and intercepts to compute prediction
    m_tmp_a = model_tmp.coef_[0][0]
    m_tmp_b = model_tmp.coef_[0][1]
    q_tmp = model_tmp.intercept_

    # use current time to make the prediction
    tpa = ts.iloc[i,0] 
    tpb = ts.iloc[i,1]
    yp = m_tmp_a * tpa + m_tmp_b * tpb + q_tmp
      
    # in order to associate the predicted value with future time,
    # add ph to current time step for visualization
    tp_pred[i-2] = tpa + ph   
    yp_pred[i-2] = yp

# %% [markdown]
# #### Model Validation

# %% [markdown]
# Lets now visualize the results from our model

# %%
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Room CO2 Prediction', fontsize=22, fontweight='bold')
ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot(tp_pred, yp_pred, label='Predicted Value')
ax.plot(ts.iloc[0:n_s,0], ys.iloc[0:n_s,0], label='CO2 data')
ax.set_xlabel('time (epoch)')
ax.set_ylabel('ppm')
ax.legend()

# %% [markdown]
# It’s difficult to tell how the model is performing from this plot. Lets visualize the first and last 200 datapoints/prediction

# %%
#Plot first 200 data points/predictions
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Room CO2 Prediction - First 200 Points', fontsize=22, fontweight='bold')
ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot(tp_pred[0:200], yp_pred[0:200], label='Predicted Value')
ax.plot(ts.iloc[0:200,0], ys.iloc[0:200,0], label='CO2')
ax.set_xlabel('time (epoch)')
ax.set_ylabel('ppm')
ax.legend()

# %%
#Plot last 200 data points/predictions
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Room CO2 Prediction - Last 200 Points', fontsize=22, fontweight='bold')
ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot(tp_pred[-200:], yp_pred[-200:], label='Predicted Value')
ax.plot(ts.iloc[n_s-200:n_s,0], ys.iloc[n_s-200:n_s,0], label='CO2 data')
ax.set_xlabel('time (epoch)')
ax.set_ylabel('ppm')
ax.legend()

# %% [markdown]
# ### XGBoost

# %% [markdown]
# Pretrain the model based on previouse data set and compare results produced

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[['Temp', 'Light', 'Sound', 'Room_Occupancy_Count']], df['CO2'], test_size=0.2, random_state=2000000)

# Define the XGBoost model
xgb_model = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate=0.25,
                max_depth=5000, n_estimators=100)

# Train the XGBoost model
xgb_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = xgb_model.predict(X_test)

# Evaluate the model using mean squared error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 198.81396805401937

# %% [markdown]
# As we can see MSE is neither ideal nor it is bad. It shows that there are some outliers during the test and a model relativelly costly.

# %% [markdown]
# Plot lust 100 steps

# %%
# Set the figure size
plt.figure(figsize=(15, 15))

# Plot the last 100 actual CO2 values and the predicted values over time
plt.plot(y_test.values[-100:], label='Actual')
plt.plot(y_pred[-100:], label='Predicted')
plt.xlabel('Time')
plt.ylabel('CO2')
plt.legend()
plt.show()

# %% [markdown]
# Plot first 100 steps

# %%
# Set the figure size
plt.figure(figsize=(15, 15))

# Plot the first 100 actual CO2 values and the predicted values over time
plt.plot(y_test.values[0:100], label='Actual')
plt.plot(y_pred[0:100], label='Predicted')
plt.xlabel('Time')
plt.ylabel('CO2')
plt.legend()
plt.show()

# %% [markdown]
# As we can see the results produced at the end and at the bgining are slightly different. It seems that most of MSE generated during initial traning. On the other hand, those errors does not seem to be so dramatic.

# %% [markdown]
# Let's calculate RMSE and R^2 which are more opropriate for a gradient booster models

# %%
# Calculate root mean squared error (RMSE) and R2 score for the predictions
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# Print the RMSE and R2 score
print("RMSE:", rmse)
print("R2 score:", r2)
# Out:
# RMSE: 14.100140710433331
# R2 score: 0.9950859496135938

# %% [markdown]
# It is great, as it is shown RMSE is small and results are very accurate where RMSE = 10.155 and R^2 = 0.9944. Nevertheless, higher MSE is a concern. It lead us to believe that we need to calculate MAE.

# %%
# Mean absolute error
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 6.305715623047839

# %% [markdown]
# MAE = 4.419 is a fantastic result. It means the difference between model's and actual data is in a magnitude of 4.419 which is very small considering that avg number is higher than 100

# %% [markdown]
# Let's calculate F1-score

# %%
# Convert CO2 levels to binary occupancy labels using a threshold of 1000 ppm
y_test_occ = np.where(y_test > 1000, 1, 0)
y_pred_occ = np.where(y_pred > 1000, 1, 0)

# Calculate precision, recall, F1-score and support for each class (occupied and unoccupied)
precision, recall, f1, support = precision_recall_fscore_support(y_test_occ, y_pred_occ)

# Print the F1-score for the occupied class
print("F1-score for occupied class:", f1[1])
# Out:
# F1-score for occupied class: 0.9397590361445783

# %% [markdown]
# As we can see F1-score is substantially less than R^2 it is due to many factors such as recall. In other words, higher accuracy does not mean that model will performe well.

# %% [markdown]
# ### Results/Conclusions

# %% [markdown]
# Compute the MSE for our predictions

# %%
#print mse results
def mse(y_true, y_pred):
    """Calculate the mean squared error between two arrays"""
    return np.mean((y_true - y_pred)**2)

# Calculate MSE of predictions
print("MSE is", mse(ys['CO2'][ph_index:3000+ph_index-1], yp_pred))
# Out:
# MSE is 38.15958827971281

# %% [markdown]
# The model performed OK. It could have been better had the dataset size been larger and with more data captured during working days. You can see that the predictions are slightly lagging behind the actual
# data, due to the 30 second prediction horizon. With the quality and quantity of dataset the MSE is on the lower side, due to which the predictions are fair.

# %% [markdown]
# # Cleaned Data Results

# %%
from scipy import stats

# define a threshold value for the z-score
threshold = 3

# select the columns we want to clean
selected_columns = ['Temp', 'Light', 'Sound', 'CO2', 'CO2_Slope', 'PIR_S1', 'PIR_S2', 'Room_Occupancy_Count']
selected_df = df[selected_columns]

# calculate the z-scores for each column in the dataframe
z_scores = stats.zscore(selected_df)

# get the absolute z-scores for each data point
abs_z_scores = np.abs(z_scores)

# create a boolean mask for each row, indicating whether it's an outlier or not
mask = (abs_z_scores < threshold).all(axis=1)

# create a new dataframe with the cleaned data
clean_df = df[mask]

# save the cleaned dataframe to a new CSV file
clean_df.to_csv('cleaned_data.csv', index=False)

# %%
df = clean_df

# %%
# create violinplots for each feature
fig, axs = plt.subplots(4, 2, figsize=(10, 20))

sns.violinplot(data=df, x='Temp', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[0, 0])
sns.violinplot(data=df, x='Light', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[0, 1])
sns.violinplot(data=df, x='Sound', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[1, 0])
sns.violinplot(data=df, x='CO2', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[1, 1])
sns.violinplot(data=df, x='CO2_Slope', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[2, 0])
sns.violinplot(data=df, x='PIR_S1', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[2, 1])
sns.violinplot(data=df, x='PIR_S2', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[3, 0])
sns.violinplot(data=df, x='Room_Occupancy_Count', width=.3, linewidth=2, fliersize=5, showfliers=False, ax=axs[3, 1])

plt.show()

# %% [markdown]
# We can see that the Room Occupancy is empty (i.e., 0) for the majority of the time readings were collected.  This explains why most of our data does not appear to be normally distributed.  Most values are skewed to the left, indicating no or low sensor readings while rooms are vacant.  We will likely need to consider data tranformations and/or normalizations prior to training our machine learning models.

# %%
# calculate the skewness
Temp_skewness = skew(df['Temp'])
Light_skewness = skew(df['Light'])
Sound_skewness = skew(df['Sound'])
CO2_skewness = skew(df['CO2'])
CO2_Slope_skewness = skew(df['CO2_Slope'])
PIR_S1_skewness = skew(df['PIR_S1'])
PIR_S2_skewness = skew(df['PIR_S2'])
Room_Occupancy_Count_skewness = skew(df['Room_Occupancy_Count'])

print(f"Skewness Temp = {Temp_skewness:.2f}")
print(f"Skewness Light = {Light_skewness:.2f}")
print(f"Skewness Sound = {Sound_skewness:.2f}")
print(f"Skewness CO2 = {CO2_skewness:.2f}")
print(f"Skewness CO2_Slope = {CO2_Slope_skewness:.2f}")
print(f"Skewness PIR_S1 = {PIR_S1_skewness:.2f}")
print(f"Skewness PIR_S2 = {PIR_S2_skewness:.2f}")
print(f"Skewness Room_Occupancy_Count = {Room_Occupancy_Count_skewness:.2f}")
# Out:
# Skewness Temp = 1.18
# Skewness Light = 3.45
# Skewness Sound = 6.76
# Skewness CO2 = 2.79
# Skewness CO2_Slope = -0.98
# Skewness PIR_S1 = 0.00
# Skewness PIR_S2 = 0.00
# Skewness Room_Occupancy_Count = 4.33

# %%
# find relationship between columns in form of a heat map
sns.heatmap(df.corr(), annot=True, fmt=".1f", mask=np.triu(df.corr()));

# %% [markdown]
# ## Machine Learning Tasks

# %% [markdown]
# ### Task 1a - Deep Learning LSTM Time Series Prediction for Room Occupancy Count

# %%
# create new copy of dataframe
df_lstm = df.copy()
# find location which splits df_lstm into 80% and 20%
loc_split = round((df_lstm.shape[0]*.80))

# create train_df using 80% of df_lstm
train_df = df_lstm.iloc[0:loc_split]

# create val_df using remaining 20% of df_lstm
val_df = df_lstm.iloc[loc_split:]

# reset validation dataframe index for cleanliness
val_df = val_df.reset_index()

# MinMax normalization (from 0 to 1)

# select columns to normalize, exclude non-numeric, Datetime, PIR sensors, and output feature
cols_normalize = train_df.columns.difference(['Date', 'Time', 'Datetime', 'Room_Occupancy_Count'])

# scale selected columns between 0 and 1
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)

# recombine scaled columns with the training dataframe
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

# define sequence length and prediction horizon
seq_length = 25
ph = 1

# pick the feature columns 
feat_cols = ['Temp']

# create nested list structure
seq_arrays = []
seq_labs = []

# create list of sequence length temperature readings
rlen = len(train_df) - seq_length - ph
for start in range(0, rlen):
    seq_arrays.append(train_df[feat_cols].iloc[start:start+seq_length].to_numpy())
    seq_labs.append([train_df['Room_Occupancy_Count'].iloc[start:start+seq_length+ph].to_numpy()[-1]])
    
#convert to numpy arrays and floats to appease keras/tensorflow        
seq_arrays = np.array(seq_arrays, dtype = object).astype(np.float32)
seq_labs = np.array(seq_labs, dtype = object).astype(np.float32)

# assert statements to verify we have our expected array shapes
assert(seq_arrays.shape == (len(train_df)-seq_length-ph, seq_length, len(feat_cols)))
assert(seq_labs.shape == (len(train_df)-seq_length-ph, 1))

#########MODEL TRAINING########
# define path to save model
model_path = 'LSTM_model1.h5'

# build the network
nb_features = seq_arrays.shape[2]
nb_out = seq_labs.shape[1]

# create sequential model object
model = Sequential()

#add first LSTM layer
model.add(LSTM(
         input_shape=(seq_length, nb_features),
         units=5, 
         return_sequences=True))
model.add(Dropout(0.2)) 

# add second LSTM layer
model.add(LSTM(
          units=3,
          return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=nb_out))
model.add(Activation('linear'))
optimizer = keras.optimizers.Adam(learning_rate = 0.005)
model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mse'])

# print model summary
print(model.summary())

# fit the model
history = model.fit(seq_arrays, seq_labs, epochs=100, batch_size=125, validation_split=0.05, verbose=2,
          callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=0, mode='min'),
                       keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
          )

# list all data in history
print(history.history.keys())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 25, 5)             140
#
#  dropout_6 (Dropout)         (None, 25, 5)             0
#
#  lstm_7 (LSTM)               (None, 3)                 108
#
#  dropout_7 (Dropout)         (None, 3)                 0
#
#  dense_7 (Dense)             (None, 1)                 4
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 252
# Trainable params: 252
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 53/53 - 7s - loss: 0.1883 - mse: 0.1883 - val_loss: 0.7923 - val_mse: 0.7923 - 7s/epoch - 137ms/step
# Epoch 2/100
# 53/53 - 1s - loss: 0.1679 - mse: 0.1679 - val_loss: 0.7811 - val_mse: 0.7811 - 946ms/epoch - 18ms/step
# Epoch 3/100
# 53/53 - 1s - loss: 0.1653 - mse: 0.1653 - val_loss: 0.7912 - val_mse: 0.7912 - 871ms/epoch - 16ms/step
# Epoch 4/100
# 53/53 - 1s - loss: 0.1583 - mse: 0.1583 - val_loss: 0.7446 - val_mse: 0.7446 - 999ms/epoch - 19ms/step
# Epoch 5/100
# 53/53 - 1s - loss: 0.1574 - mse: 0.1574 - val_loss: 0.7496 - val_mse: 0.7496 - 864ms/epoch - 16ms/step
# Epoch 6/100
# 53/53 - 1s - loss: 0.1536 - mse: 0.1536 - val_loss: 0.6441 - val_mse: 0.6441 - 874ms/epoch - 16ms/step
# Epoch 7/100
# 53/53 - 1s - loss: 0.1484 - mse: 0.1484 - val_loss: 0.6005 - val_mse: 0.6005 - 985ms/epoch - 19ms/step
# Epoch 8/100
# 53/53 - 1s - loss: 0.1530 - mse: 0.1530 - val_loss: 0.6591 - val_mse: 0.6591 - 1s/epoch - 19ms/step
# Epoch 9/100
# 53/53 - 1s - loss: 0.1506 - mse: 0.1506 - val_loss: 0.5784 - val_mse: 0.5784 - 973ms/epoch - 18ms/step
# Epoch 10/100
# 53/53 - 1s - loss: 0.1394 - mse: 0.1394 - val_loss: 0.6991 - val_mse: 0.6991 - 1s/epoch - 22ms/step
# Epoch 11/100
# 53/53 - 1s - loss: 0.1298 - mse: 0.1298 - val_loss: 0.4935 - val_mse: 0.4935 - 1s/epoch - 22ms/step
# Epoch 12/100
# 53/53 - 1s - loss: 0.1361 - mse: 0.1361 - val_loss: 0.4420 - val_mse: 0.4420 - 1s/epoch - 21ms/step
# Epoch 13/100
# 53/53 - 1s - loss: 0.1359 - mse: 0.1359 - val_loss: 0.4205 - val_mse: 0.4205 - 902ms/epoch - 17ms/step
# Epoch 14/100
# 53/53 - 1s - loss: 0.1221 - mse: 0.1221 - val_loss: 0.4190 - val_mse: 0.4190 - 978ms/epoch - 18ms/step
# Epoch 15/100
# 53/53 - 1s - loss: 0.1205 - mse: 0.1205 - val_loss: 0.5264 - val_mse: 0.5264 - 906ms/epoch - 17ms/step
# Epoch 16/100
# 53/53 - 1s - loss: 0.1189 - mse: 0.1189 - val_loss: 0.4049 - val_mse: 0.4049 - 872ms/epoch - 16ms/step
# Epoch 17/100
# 53/53 - 1s - loss: 0.1156 - mse: 0.1156 - val_loss: 0.4623 - val_mse: 0.4623 - 903ms/epoch - 17ms/step
# Epoch 18/100
# 53/53 - 1s - loss: 0.1206 - mse: 0.1206 - val_loss: 0.4232 - val_mse: 0.4232 - 845ms/epoch - 16ms/step
# Epoch 19/100
# 53/53 - 1s - loss: 0.1118 - mse: 0.1118 - val_loss: 0.4359 - val_mse: 0.4359 - 908ms/epoch - 17ms/step
# Epoch 20/100
# 53/53 - 1s - loss: 0.1206 - mse: 0.1206 - val_loss: 0.3516 - val_mse: 0.3516 - 1s/epoch - 20ms/step
# Epoch 21/100
# 53/53 - 1s - loss: 0.1086 - mse: 0.1086 - val_loss: 0.3511 - val_mse: 0.3511 - 928ms/epoch - 18ms/step
# Epoch 22/100
# 53/53 - 1s - loss: 0.1134 - mse: 0.1134 - val_loss: 0.3490 - val_mse: 0.3490 - 1s/epoch - 19ms/step
# Epoch 23/100
# 53/53 - 1s - loss: 0.1095 - mse: 0.1095 - val_loss: 0.3611 - val_mse: 0.3611 - 934ms/epoch - 18ms/step
# Epoch 24/100
# 53/53 - 1s - loss: 0.1052 - mse: 0.1052 - val_loss: 0.3639 - val_mse: 0.3639 - 1s/epoch - 20ms/step
# Epoch 25/100
# 53/53 - 1s - loss: 0.1052 - mse: 0.1052 - val_loss: 0.3136 - val_mse: 0.3136 - 1s/epoch - 23ms/step
# Epoch 26/100
# 53/53 - 1s - loss: 0.1005 - mse: 0.1005 - val_loss: 0.3418 - val_mse: 0.3418 - 1s/epoch - 20ms/step
# Epoch 27/100
# 53/53 - 1s - loss: 0.1045 - mse: 0.1045 - val_loss: 0.3143 - val_mse: 0.3143 - 1s/epoch - 21ms/step
# Epoch 28/100
# 53/53 - 1s - loss: 0.0998 - mse: 0.0998 - val_loss: 0.3366 - val_mse: 0.3366 - 880ms/epoch - 17ms/step
# Epoch 29/100
# 53/53 - 1s - loss: 0.1011 - mse: 0.1011 - val_loss: 0.3127 - val_mse: 0.3127 - 892ms/epoch - 17ms/step
# Epoch 30/100
# 53/53 - 1s - loss: 0.1045 - mse: 0.1045 - val_loss: 0.3206 - val_mse: 0.3206 - 843ms/epoch - 16ms/step
# Epoch 31/100
# 53/53 - 1s - loss: 0.0901 - mse: 0.0901 - val_loss: 0.2842 - val_mse: 0.2842 - 911ms/epoch - 17ms/step
# Epoch 32/100
# 53/53 - 1s - loss: 0.0919 - mse: 0.0919 - val_loss: 0.2829 - val_mse: 0.2829 - 901ms/epoch - 17ms/step
# Epoch 33/100
# 53/53 - 1s - loss: 0.0907 - mse: 0.0907 - val_loss: 0.2674 - val_mse: 0.2674 - 931ms/epoch - 18ms/step
# Epoch 34/100
# 53/53 - 1s - loss: 0.0998 - mse: 0.0998 - val_loss: 0.2705 - val_mse: 0.2705 - 874ms/epoch - 16ms/step
# Epoch 35/100
# 53/53 - 1s - loss: 0.0919 - mse: 0.0919 - val_loss: 0.2856 - val_mse: 0.2856 - 833ms/epoch - 16ms/step
# Epoch 36/100
# 53/53 - 1s - loss: 0.0939 - mse: 0.0939 - val_loss: 0.2683 - val_mse: 0.2683 - 868ms/epoch - 16ms/step
# Epoch 37/100
# 53/53 - 1s - loss: 0.0921 - mse: 0.0921 - val_loss: 0.2661 - val_mse: 0.2661 - 869ms/epoch - 16ms/step
# Epoch 38/100
# 53/53 - 1s - loss: 0.0902 - mse: 0.0902 - val_loss: 0.2958 - val_mse: 0.2958 - 863ms/epoch - 16ms/step
# Epoch 39/100
# 53/53 - 1s - loss: 0.0902 - mse: 0.0902 - val_loss: 0.2727 - val_mse: 0.2727 - 841ms/epoch - 16ms/step
# Epoch 40/100
# 53/53 - 1s - loss: 0.0855 - mse: 0.0855 - val_loss: 0.2607 - val_mse: 0.2607 - 910ms/epoch - 17ms/step
# Epoch 41/100
# 53/53 - 1s - loss: 0.0993 - mse: 0.0993 - val_loss: 0.2650 - val_mse: 0.2650 - 926ms/epoch - 17ms/step
# Epoch 42/100
# 53/53 - 1s - loss: 0.0906 - mse: 0.0906 - val_loss: 0.2757 - val_mse: 0.2757 - 852ms/epoch - 16ms/step
# Epoch 43/100
# 53/53 - 1s - loss: 0.0908 - mse: 0.0908 - val_loss: 0.2546 - val_mse: 0.2546 - 884ms/epoch - 17ms/step
# Epoch 44/100
# 53/53 - 1s - loss: 0.1206 - mse: 0.1206 - val_loss: 0.3226 - val_mse: 0.3226 - 827ms/epoch - 16ms/step
# Epoch 45/100
# 53/53 - 1s - loss: 0.0966 - mse: 0.0966 - val_loss: 0.2919 - val_mse: 0.2919 - 849ms/epoch - 16ms/step
# Epoch 46/100
# 53/53 - 1s - loss: 0.0939 - mse: 0.0939 - val_loss: 0.2775 - val_mse: 0.2775 - 838ms/epoch - 16ms/step
# Epoch 47/100
# 53/53 - 1s - loss: 0.0908 - mse: 0.0908 - val_loss: 0.2870 - val_mse: 0.2870 - 918ms/epoch - 17ms/step
# Epoch 48/100
# 53/53 - 1s - loss: 0.0979 - mse: 0.0979 - val_loss: 0.2544 - val_mse: 0.2544 - 1s/epoch - 19ms/step
# Epoch 49/100
# 53/53 - 1s - loss: 0.0927 - mse: 0.0927 - val_loss: 0.3066 - val_mse: 0.3066 - 859ms/epoch - 16ms/step
# Epoch 50/100
# 53/53 - 1s - loss: 0.0919 - mse: 0.0919 - val_loss: 0.2870 - val_mse: 0.2870 - 874ms/epoch - 16ms/step
# Epoch 51/100
# 53/53 - 1s - loss: 0.0851 - mse: 0.0851 - val_loss: 0.2691 - val_mse: 0.2691 - 847ms/epoch - 16ms/step
# Epoch 52/100
# 53/53 - 1s - loss: 0.0858 - mse: 0.0858 - val_loss: 0.2607 - val_mse: 0.2607 - 925ms/epoch - 17ms/step
# Epoch 53/100
# 53/53 - 1s - loss: 0.0870 - mse: 0.0870 - val_loss: 0.2628 - val_mse: 0.2628 - 917ms/epoch - 17ms/step
# Epoch 54/100
# 53/53 - 1s - loss: 0.0852 - mse: 0.0852 - val_loss: 0.2892 - val_mse: 0.2892 - 973ms/epoch - 18ms/step
# Epoch 55/100
# 53/53 - 1s - loss: 0.0782 - mse: 0.0782 - val_loss: 0.2765 - val_mse: 0.2765 - 875ms/epoch - 17ms/step
# Epoch 56/100
# 53/53 - 1s - loss: 0.0924 - mse: 0.0924 - val_loss: 0.2811 - val_mse: 0.2811 - 857ms/epoch - 16ms/step
# Epoch 57/100
# 53/53 - 1s - loss: 0.0858 - mse: 0.0858 - val_loss: 0.2901 - val_mse: 0.2901 - 977ms/epoch - 18ms/step
# Epoch 58/100
# 53/53 - 1s - loss: 0.0850 - mse: 0.0850 - val_loss: 0.2609 - val_mse: 0.2609 - 923ms/epoch - 17ms/step
# Epoch 59/100
# 53/53 - 1s - loss: 0.0832 - mse: 0.0832 - val_loss: 0.2801 - val_mse: 0.2801 - 963ms/epoch - 18ms/step
# Epoch 60/100
# 53/53 - 1s - loss: 0.0832 - mse: 0.0832 - val_loss: 0.3010 - val_mse: 0.3010 - 861ms/epoch - 16ms/step
# Epoch 61/100
# 53/53 - 1s - loss: 0.0981 - mse: 0.0981 - val_loss: 0.2912 - val_mse: 0.2912 - 1s/epoch - 21ms/step
# Epoch 62/100
# 53/53 - 1s - loss: 0.0866 - mse: 0.0866 - val_loss: 0.2787 - val_mse: 0.2787 - 1s/epoch - 23ms/step
# Epoch 63/100
# 53/53 - 1s - loss: 0.0918 - mse: 0.0918 - val_loss: 0.2803 - val_mse: 0.2803 - 1s/epoch - 20ms/step
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %% [markdown]
# #### Plot the results

# %%
# summarize history for MSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('model MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("LSTM_mse1.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("LSTM_loss1.png")

# %% [markdown]
# #### Model Validation

# %% [markdown]
# In order to validate our model, we will create a simulated "production" dataset.  This will mimic a streaming dataset, so any data sequences less than our defined sequence length will be padded with zeroes to ensure the correct sequence length is used until the number of readings streamed equal the defined sequence length.

# %%
# create arrays for validation dataset inputs and output
val_arrays = []
val_labs = []

# create list of temperature readings starting with a minimum of two readings
rlen = len(val_df) - ph
for end in range(2, rlen):
    if (end < seq_length):
        val_arrays.append(val_df[feat_cols][0:end].to_numpy())
        val_labs.append(val_df['Room_Occupancy_Count'][end+ph])
    # add sequences of defined seq_length once we have enough readings
    else:
        val_arrays.append(val_df[feat_cols][end-seq_length:end].to_numpy())
        val_labs.append(val_df['Room_Occupancy_Count'][end+ph])

# use pad_sequences function on input sequences, specify np.float32 to appease keras/tensorflow
val_arrays = pad_sequences(val_arrays, maxlen = seq_length, dtype = np.float32)

#convert labels to numpy arrays and floats to appease keras/tensorflow
val_labs = np.array(val_labs, dtype = object).astype(np.float32)

# %%
scores_test = model.evaluate(val_arrays, val_labs, verbose=2)
print('\nMSE: {}'.format(scores_test[1]))

y_pred_test = model.predict(val_arrays)
y_pred_test2 = np.floor(y_pred_test) # round down to nearest integer
y_true_test = val_labs

test_set = pd.DataFrame(y_pred_test2)
test_set.to_csv('submit_test.csv', index = None)

# plot the predicted data vs. the actual data
# we will limit our plot to the last 2000 predictions for better visualization
fig_verify = plt.figure(figsize=(10, 5))
plt.plot(y_pred_test2[-2000:], label = 'Predicted Value')
plt.plot(y_true_test[-2000:], label = 'Actual Value')
plt.title('Room Occupancy Count Prediction - Last 2000 Points', fontsize=22, fontweight='bold')
plt.ylabel('value')
plt.xlabel('row')
plt.legend()
plt.show()
fig_verify.savefig("model_regression_verify.png")
# Out:
# 55/55 - 1s - loss: 4.8759 - mse: 4.8759 - 1s/epoch - 25ms/step
#
# MSE: 4.87588357925415
# 55/55 [==============================] - 1s 4ms/step

# %% [markdown]
# Our validation did not perform as well as our previous test data.  Unfortunately, we believe this is, in part, because of the lack of sufficient data.  The majority of our validation data has 0 for the true value of Room Occupancy Count.  We can take a look at the breakdown of our output feature's actual values.

# %%
# print output feature value counts for both the original dataframe and validation dataframe
print ('Original Dataframe:\n',(df_raw.groupby(['Room_Occupancy_Count'])['Room_Occupancy_Count'].count()))
print ('\nValidation Dataframe:\n',(val_df.groupby(['Room_Occupancy_Count'])['Room_Occupancy_Count'].count()))
# Out:
# Original Dataframe:
#  Room_Occupancy_Count
# 0    8228
# 1     459
# 2     748
# 3     694
# Name: Room_Occupancy_Count, dtype: int64
#
# Validation Dataframe:
#  Room_Occupancy_Count
# 0    1741
# Name: Room_Occupancy_Count, dtype: int64

# %% [markdown]
# ### Task 1b - Deep Learning Model Prediction for Room Occupancy Count

# %%
df_dl = df.copy()
# Divide the data in to features - X and labels - y (Room_Occupancy_Count)

labels = df_dl.pop('Room_Occupancy_Count').values.astype('float32')
features = df_dl.iloc[:,3:].values.astype('float32') # All the sensor readings except for Room_Occupancy_count
# Divide the data into train set, validation set, and test set

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=.1) 
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=.1)
# Use MinMaxScaler to normalize the input data

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)
# Change the labels dataset to one_hot. With one-hot, we convert each categorical value into a new categorical 
# column and assign a binary value of 1 or 0 to those columns. Here count values are one of - 0, 1, 2 or 3.

y_train, y_valid, y_test = to_categorical(y_train),to_categorical(y_valid), to_categorical(y_test)

# half the learning rate when val_loss stop reduce during training
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                               patience=3,
                                                               verbose=0,
                                                               factor=.5,
                                                               min_lr=.00001)

# %%
model_class = tf.keras.Sequential([
    tf.keras.layers.Dense(128,activation='relu',input_shape=[7]),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(4,activation='softmax') # Output 4 units representing the Occupancy Number 0, 1, 2, 3
])

model_class.compile(loss='categorical_crossentropy',
             optimizer=tf.keras.optimizers.Adam(),
             metrics=['accuracy'])

print(model_class.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 128)               1024
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dense_11 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 34,564
# Trainable params: 34,564
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model_class.fit(X_train_scaled,y_train,
                epochs=50,
                batch_size=32,
                validation_data=(X_valid_scaled,y_valid),
                callbacks=[learning_rate_reduction],
                verbose=1)

# list all data in history
print(history.history.keys())
# Out:
# Epoch 1/50
# 221/221 [==============================] - 2s 5ms/step - loss: 0.2322 - accuracy: 0.9543 - val_loss: 0.0474 - val_accuracy: 0.9911 - lr: 0.0010
# Epoch 2/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0479 - accuracy: 0.9884 - val_loss: 0.0282 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 3/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0272 - accuracy: 0.9925 - val_loss: 0.0149 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 4/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0180 - accuracy: 0.9945 - val_loss: 0.0067 - val_accuracy: 0.9987 - lr: 0.0010
# Epoch 5/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0051 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.0041 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0089 - val_accuracy: 0.9962 - lr: 0.0010
# Epoch 8/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.0082 - val_accuracy: 0.9974 - lr: 0.0010
# Epoch 10/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 12/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0091 - val_accuracy: 0.9974 - lr: 0.0010
# Epoch 13/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.0013 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.0099 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 15/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0013 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 16/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 9.3491e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 17/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0017 - val_accuracy: 0.9987 - lr: 5.0000e-04
# Epoch 18/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.0027 - val_accuracy: 0.9987 - lr: 5.0000e-04
# Epoch 19/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 6.5645e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 20/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0047 - accuracy: 0.9980 - val_loss: 0.0013 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 21/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 6.8727e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 22/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 9.1466e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 23/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 7.8953e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 24/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.0041 - val_accuracy: 0.9974 - lr: 2.5000e-04
# Epoch 25/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 26/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 27/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0022 - val_accuracy: 0.9987 - lr: 1.2500e-04
# Epoch 28/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 29/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 30/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0029 - accuracy: 0.9986 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 6.2500e-05
# Epoch 31/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 6.2500e-05
# Epoch 32/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0017 - val_accuracy: 0.9987 - lr: 3.1250e-05
# Epoch 33/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0028 - accuracy: 0.9987 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 3.1250e-05
# Epoch 34/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0015 - val_accuracy: 0.9987 - lr: 3.1250e-05
# Epoch 35/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.5625e-05
# Epoch 36/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.5625e-05
# Epoch 37/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0015 - val_accuracy: 0.9987 - lr: 1.5625e-05
# Epoch 38/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 39/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 40/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 41/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 42/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 43/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0015 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 44/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 45/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 46/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0017 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 47/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 48/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0017 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 49/50
# 221/221 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0017 - val_accuracy: 0.9987 - lr: 1.0000e-05
# Epoch 50/50
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0016 - val_accuracy: 0.9987 - lr: 1.0000e-05
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# summarize history for Accuracy
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_accuracy.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_loss.png")

# training metrics
scores = model_class.evaluate(X_train_scaled, y_train, verbose=1, batch_size=32)
print('Accuracy: {}'.format(scores[1]))

# make predictions and compute confusion matrix
y_pred = model_class.predict(X_train_scaled,verbose=1, batch_size=32)
y_pred = np.argmax(y_pred, axis=1)
# y_true = y_train
y_true = np.argmax(y_train, axis=1)

test_set = pd.DataFrame(y_pred)
test_set.to_csv('binary_submit_train.csv', index = None)

print('Confusion matrix\n- x-axis is true labels.\n- y-axis is predicted labels')
cm = confusion_matrix(y_true, y_pred)
print(cm)

# compute precision and recall
precision = precision_score(y_true, y_pred, average='micro')
#recall = recall_score(y_true, y_pred.round, average='micro')
#print( 'precision = ', precision, '\n', 'recall = ', recall)
print( 'precision = ', precision, '\n')
# Out:
# 221/221 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.9989
# Accuracy: 0.9988654255867004
# 221/221 [==============================] - 0s 1ms/step
# Confusion matrix
# - x-axis is true labels.
# - y-axis is predicted labels
# [[6542    0    0    0]
#  [   0  245    0    0]
#  [   0    0  186    6]
#  [   1    0    1   70]]
# precision =  0.998865409161821

# %%
def process_data(data):
    return np.array(tf.argmax(data,axis=1),dtype='float32')

y_pred = process_data(model_class.predict(X_test_scaled))

print(classification_report(tf.argmax(y_test,axis=1),y_pred))
# Out:
# 28/28 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       810
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        34
#            3       1.00      1.00      1.00         6
#
#     accuracy                           1.00       871
#    macro avg       1.00      1.00      1.00       871
# weighted avg       1.00      1.00      1.00       871

# %%
cf_matrix = confusion_matrix(tf.argmax(y_test, axis=1),y_pred)
sns.set_theme(style='whitegrid',rc={'figure.figsize':(12,5)})

fig, axs = plt.subplots(1,2)

# Number count
ax1 = sns.heatmap(cf_matrix,annot=True,cmap='Reds', ax=axs[0], fmt="g")
ax1.set_title('Room Occupancy Prediction Count')

# Percentage
ax2 = sns.heatmap(cf_matrix/np.sum(cf_matrix),annot=True,fmt='.2%',cmap='Blues',ax=axs[1])
ax2.set_title('Room Occupancy Prediction in %');

# %% [markdown]
# ### Task 2 - Multiple Regression Model Prediction for CO2

# %% [markdown]
# #### Load and pre-train model

# %%
# create new dataframe with raw data
df_mr = df.copy()
#convert datetime to epoch/unix time. In this dataset, readings are done every 30 seconds.
df_mr['time'] = (pd.to_datetime(df_mr.Datetime)-pd.to_datetime('1970-01-01')).dt.total_seconds()
#add to the x-variables in our dataset
x_variables = ['time', 'Temp']
ts = df_mr[x_variables]
ys = pd.DataFrame(df_mr.CO2)
#ys = pd.DataFrame(df_mr.Light)

ph = 0.5*60 # 0.5 minutes or 30 seconds
###############################################################
#WE NEED TO CONVERT OUR PREDICTIVE HORIZON INTO A NUMBER OF
#TIME STEPS FOR INDEXING, BASED ON THE RESOLUTION OF OUR DATA.
#IN THIS CASE OUR DATA IS COLLECTED EVERY 30 seconds
##############################################################
ph_index = round(ph/30)
mu = 0.9

n_s = 3000

# Arrays to hold predicted values
tp_pred = np.zeros(n_s-1)
yp_pred = np.zeros(n_s-1)

# %%
# At every iteration of the for loop a new data sample is acquired
# start with 2 leading datapoints

for i in range(2, n_s+1):
    
    # get x and y data
    # subtract 1 so that we don't give the model access to future data
    ts_tmp = ts[0:i-1] 
    
    # Use the value at the predictive horizon index as the predicted 
    # value for training
    ys_tmp = ys[ph_index-1:ph_index-1+i-1]
    
    ns = len(ys_tmp)
    
    weights = np.ones(ns)*mu
    
    for k in range(ns):
        weights[k] = weights[k]**k # weights are downweighted as per timestamp away from prediction
        
    weights = np.flip(weights, 0)
    
    #perform linear regression on "available" data using the mu-adjusted weights
    lm_tmp = LinearRegression()
    model_tmp = lm_tmp.fit(ts_tmp, ys_tmp, sample_weight=weights)
    
    #store model coefficients and intercepts to compute prediction
    m_tmp_a = model_tmp.coef_[0][0]
    m_tmp_b = model_tmp.coef_[0][1]
    q_tmp = model_tmp.intercept_

    # use current time to make the prediction
    tpa = ts.iloc[i,0] 
    tpb = ts.iloc[i,1]
    yp = m_tmp_a * tpa + m_tmp_b * tpb + q_tmp
      
    # in order to associate the predicted value with future time,
    # add ph to current time step for visualization
    tp_pred[i-2] = tpa + ph   
    yp_pred[i-2] = yp

    
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Room CO2 Prediction', fontsize=22, fontweight='bold')
ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot(tp_pred, yp_pred, label='Predicted Value')
ax.plot(ts.iloc[0:n_s,0], ys.iloc[0:n_s,0], label='CO2 data')
ax.set_xlabel('time (epoch)')
ax.set_ylabel('ppm')
ax.legend()
#Plot first 200 data points/predictions
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Room CO2 Prediction - First 200 Points', fontsize=22, fontweight='bold')
ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot(tp_pred[0:200], yp_pred[0:200], label='Predicted Value')
ax.plot(ts.iloc[0:200,0], ys.iloc[0:200,0], label='CO2')
ax.set_xlabel('time (epoch)')
ax.set_ylabel('ppm')
ax.legend()
#Plot last 200 data points/predictions
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Room CO2 Prediction - Last 200 Points', fontsize=22, fontweight='bold')
ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot(tp_pred[-200:], yp_pred[-200:], label='Predicted Value')
ax.plot(ts.iloc[n_s-200:n_s,0], ys.iloc[n_s-200:n_s,0], label='CO2 data')
ax.set_xlabel('time (epoch)')
ax.set_ylabel('ppm')
ax.legend()

# %% [markdown]
# ### XGBoost

# %%
#Plot first 200 data points/predictions
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Room CO2 Prediction - First 200 Points', fontsize=22, fontweight='bold')
ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot(tp_pred[0:200], yp_pred[0:200], label='Predicted Value')
ax.plot(ts.iloc[0:200,0], ys.iloc[0:200,0], label='CO2')
ax.set_xlabel('time (epoch)')
ax.set_ylabel('ppm')
ax.legend()

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[['Temp', 'Light', 'Sound', 'Room_Occupancy_Count']], df['CO2'], test_size=0.2, random_state=2000000)

# Define the XGBoost model
xgb_model = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate=0.25,
                max_depth=5000, n_estimators=100)

# Train the XGBoost model
xgb_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = xgb_model.predict(X_test)

# Evaluate the model using mean squared error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 103.1183623183229

# %%
# Set the figure size
plt.figure(figsize=(15, 15))

# Plot the last 100 actual CO2 values and the predicted values over time
plt.plot(y_test.values[-100:], label='Actual')
plt.plot(y_pred[-100:], label='Predicted')
plt.xlabel('Time')
plt.ylabel('CO2')
plt.legend()
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(15, 15))

# Plot the first 100 actual CO2 values and the predicted values over time
plt.plot(y_test.values[0:100], label='Actual')
plt.plot(y_pred[0:100], label='Predicted')
plt.xlabel('Time')
plt.ylabel('CO2')
plt.legend()
plt.show()

# %%
# Calculate root mean squared error (RMSE) and R2 score for the predictions
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# Print the RMSE and R2 score
print("RMSE:", rmse)
print("R2 score:", r2)

# Mean absolute error
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# RMSE: 10.154721183682145
# R2 score: 0.9943624538864625
# Mean Absolute Error: 4.41909224185002
